# %%
# !pip install -q langchain
# !pip install -q langchain-nvidia-ai-endpoints
# !pip install -q langchain-community langchain-core
# !pip install -q --upgrade langchain
# !pip install -q pandas

# %% [markdown]
# # Test out your locally deployed NIM first

# %%
from langchain.schema import SystemMessage, HumanMessage
from langchain_nvidia_ai_endpoints import ChatNVIDIA

llm = ChatNVIDIA(
    model="nvidia/llama-3.3-nemotron-super-49b-v1",
    base_url="http://localhost:8000/v1",   # your local NIM /v1
)

messages = [
    # Change this to on if you want to use reasoning
    SystemMessage(content="detailed thinking off"),
    HumanMessage(content="Write a limerick about the wonders of GPU computing.")
]

response = llm(messages)
print(response)
# Out:
# /tmp/ipykernel_36956/2228743414.py:14: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(messages)
# content='Here is a limerick about the wonders of GPU computing:\n\nThere once was a GPU so bright,\nCompute tasks devoured with pure delight.\nIt processed with a flair,\nThrough threads beyond compare,\nAnd made even the hardest simulations take flight.' additional_kwargs={} response_metadata={'role': 'assistant', 'reasoning_content': None, 'content': 'Here is a limerick about the wonders of GPU computing:\n\nThere once was a GPU so bright,\nCompute tasks devoured with pure delight.\nIt processed with a flair,\nThrough threads beyond compare,\nAnd made even the hardest simulations take flight.', 'tool_calls': [], 'token_usage': {'prompt_tokens': 31, 'total_tokens': 80, 'completion_tokens': 49, 'prompt_tokens_details': None}, 'finish_reason': 'stop', 'model_name': 'nvidia/llama-3.3-nemotron-super-49b-v1'} id='run--7db3f500-d1b4-469a-b545-190d9b297bcb-0' usage_metadata={'input_tokens': 31, 'output_tokens': 49, 'total_tokens': 80} role='assistant'

# %% [markdown]
# # Classes and prompt definition for our financial domain

# %%
event_types_mapping = {"analyst rating": 0, "price targets": 1,
                       "earnings": 2, "labour related": 3, "mergers and acquisitions": 4, "dividends": 5,
                       "regulatory": 6, "stock price movement": 7, "credit ratings": 8, "products-services": 9,
                       "product approval": 10, "guidance": 11, "other": 12
                      }

# %%
prompt = """
You are a helpful AI assistant that analyses financial news headlines and identifies what event type is described.
You will classify event types into one of the following categories (in square brackets)

- [Analyst Rating]: An entity such as a bank, asset manager, etc. gives a classification/rating/downgrade/upgrade/opinion to an asset.
                    If there is no specified analyst and company given, it's not Analyst Rating and should be classified as OTHER.
- [Price Targets]: A mention of a price target (PT) is given by an entity such as bank, asset manager, etc.
                   This takes priority over any other class, so if a price target is present use this class!
- [Earnings]: Reports of quarterly, monthly, etc. concrete values of revenue, ESP, etc. Percentage fluctations.
              Expected values are not Earnings and should be Guidance instead!
- [Labour Issues]: Mentions of layoffs, union action, strikes, rising cost of labour, bonuses for execs, etc. Important personal change, e.g. CEO, CFO, VPs, etc.
- [Mergers and Acquisitions]: Whenever merging or acquisition of entities, not just companies, is mentioned.
                              Things like partnerships do not belong to this class! Takes priority over other classes.
- [Dividends]: Mentions of dividend performance, dividend per share, decisions not to issue dividends, etc.
- [Regulatory]: Mentions corporate position focused on environmental affairs, government regulation, international treaties, geopolitics, debt repayment, licenses, patents, etc.
                Any executive decisions taken by the government are Regulatory. Takes priority over other classes.
- [Stock price movement]: Includes pricing of public offerings, daily, monthly and yearly movements, highs and lows, options trade and alerts, etc.
                          Only relevant when a specific entity/industry or set of entities/industries mentioned.
                          Quantities such as sales, are not stock price movements. Stock splits do not count as stock movements.
                          Takes priority over Earnings, Stock Price Movement, Credit Ratings
- [Credit Ratings]: Adjustments of company's borrowing capacity, changes in debt values, changes in ratings, etc.
- [Products-Services]: Mentions of a company's particular product, forward-looking product directions, disruption, government and private contracts, etc.
                       Any sort of delay regarding a product roll-out, etc.
- [Product Approval]: Mentions FDA approvals, environmental approvals, acceptance for review. Any time an entity approves the rollout of a corporations product.
- [Guidance]: Forward looking statements issued by the company's themselves regarding Revenue, EPS, potential sales going up/down, number of contracts, etc.
              Similar talk to earnings but about projections rather than realised.
              
If the headline doesn't match any of the classes, classify it as OTHER.
ATTENTION:
  - Only assign a category if the headline meets all the criteria listed for that category. Otherwise use OTHER
  - Encourage precise matching rather than assigning categories based on partial or superficial similarities
  - OTHER is the default category when in doubt
  - If there are no specific companies mentioned, use OTHER

A few examples:

1. Cornerstone OnDemand Higher as Barclays Upgraded to Overweight -> [Analyst Rating]
2. HC Wainwright & Co. Maintains Buy on Balchem, Lowers Price Target to $104 -> [Price Targets]
3. Sina Reports Q4 Adj. EPS $0.24 vs $0.18 Est., Sales $211.1M vs $207.6M Est.; Sees FY15 Sales $800M-$900M vs $884.6M Est. -> [Earnings]
4. Delta To Buy Out Employees, Offer Early Retirement (DAL) -> [Labour Issues]
5. Constant Contact Announces Deal to Be Purchased by Endurance Int'l at $32/Share -> [Mergers and Acquisitions]
6. Ameriprise Financial Announces 12% Qtr. Dividend Increase to $0.58/Share -> [Dividends]
7. Ultratech Achieves ISO 9001 and 14001 Certification for Singapore Operations and Recertification for U.S. Facility  -> [Regulatory]
8. Mid-Afternoon Market Update: Dow Up Over 200 Points; Lakeland Industries Shares Spike Higher -> [Stock price movement]
9. Moody's Affirms Ratings on Nokia; Outlook Revised from Negative to Developing -> [Credit Ratings]
10. NOVAVAX Awarded HHS-BARDA Contract Valued at up to $179 Million  -> [Products-Services]
11. Sanofi's Genzyme Announces Lemtrada Resubmission Accepted for Review by FDA  -> [Product Approval]
12. Dot Hill Systems Announces Re-alignment of Software Development Initiatives; Sees Q4 EPS of $(0.02)-(0.03) vs $0.03-(0.03) Prior  -> [Guidance]
13. Kopin Chairman Fan Buys 116,400 Shares @$2.83/Share -Form 4 -> [OTHER]

Given the following headline:

### START HEADLINE ###

{headline}

### END HEADLINE ###

What event type best classifies it? Answer only with your predicted class and give it inside double square brackets, like [[class]]
"""

# %% [markdown]
# Let's look at some model predictions

# %%
import pickle
from collections import Counter


with open('manually_labelled_testset.pkl', 'rb') as f:
    test_labels = pickle.load(f)

Counter(list(test_labels.values()))
# Out:
# Counter({'Analyst Rating': 96,
#          'OTHER': 93,
#          'Mergers and Acquisitions': 88,
#          'Labour Issues': 88,
#          'Regulatory': 85,
#          'Guidance': 83,
#          'Stock price movement': 76,
#          'Earnings': 75,
#          'Product Approval': 72,
#          'Dividends': 71,
#          'Price Targets': 66,
#          'Credit Ratings': 61,
#          'Products-Services': 49,
#          'Management changes': 22})

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import threading


completed_tasks = 0  # Variable to track completed tasks
texts = [text for text in test_labels]
total_tasks = len(texts)
lock = asyncio.Lock()  # To protect shared variables during concurrent access
predictions = {}


def run(text):
    return llm.invoke(prompt.format(headline=text)).content


def save_item(item_to_save, file_name):
    with open(file_name, 'wb') as f:
        pickle.dump(item_to_save, f)
        

async def run_with_timeout(text, semaphore):
    global completed_tasks
    attempts = 0
    while True:
        attempts += 1
        try:
            async with semaphore:
                # Run the synchronous `run` function in a thread with a timeout
                result = await asyncio.wait_for(asyncio.to_thread(run, text), timeout=30)
            predictions[text] = result
            async with lock:
                completed_tasks += 1
                if completed_tasks % 20 == 0:
                    print(f"Completed {completed_tasks}/{total_tasks} tasks.")
            break  # Exit loop on success
        except asyncio.TimeoutError:
            print(f"Task for '{text}' timed out. Retrying (attempt {attempts})...")
            continue
        except Exception as e:
            # Handle other exceptions if necessary
            print(f"Task for '{text}' failed with exception {e}. Retrying (attempt {attempts})...")
            continue

async def main():
    semaphore = asyncio.Semaphore(5)
    tasks = [asyncio.create_task(run_with_timeout(text, semaphore)) for text in texts]
    await asyncio.gather(*tasks)

asyncio.run(main())
# Out:
# Completed 20/1025 tasks.
# Completed 40/1025 tasks.
# Completed 60/1025 tasks.
# Completed 80/1025 tasks.
# Completed 100/1025 tasks.
# Completed 120/1025 tasks.
# Completed 140/1025 tasks.
# Completed 160/1025 tasks.
# Completed 180/1025 tasks.
# Completed 200/1025 tasks.
# Completed 220/1025 tasks.
# Completed 240/1025 tasks.
# Completed 260/1025 tasks.
# Completed 280/1025 tasks.
# Completed 300/1025 tasks.
# Completed 320/1025 tasks.
# Completed 340/1025 tasks.
# Completed 360/1025 tasks.
# Completed 380/1025 tasks.
# Completed 400/1025 tasks.
# Completed 420/1025 tasks.
# Completed 440/1025 tasks.
# Completed 460/1025 tasks.
# Completed 480/1025 tasks.
# Completed 500/1025 tasks.
# Completed 520/1025 tasks.
# Completed 540/1025 tasks.
# Completed 560/1025 tasks.
# Completed 580/1025 tasks.
# Completed 600/1025 tasks.
# Completed 620/1025 tasks.
# Completed 640/1025 tasks.
# Completed 660/1025 tasks.
# Completed 680/1025 tasks.
# Completed 700/1025 tasks.
# Completed 720/1025 tasks.
# Completed 740/1025 tasks.
# Completed 760/1025 tasks.
# Completed 780/1025 tasks.
# Completed 800/1025 tasks.
# Completed 820/1025 tasks.
# Completed 840/1025 tasks.
# Completed 860/1025 tasks.
# Completed 880/1025 tasks.
# Completed 900/1025 tasks.
# Completed 920/1025 tasks.
# Completed 940/1025 tasks.
# Completed 960/1025 tasks.
# Completed 980/1025 tasks.
# Completed 1000/1025 tasks.
# Completed 1020/1025 tasks.

# %%
predictions
# Out:
# {'Best Dividend Stocks In The Market(JNJ, MMM, MCD, PG, ABT)': '[[Dividends]]',
#  'Mueller Water Increases Qtr. Dividend From $0.02 To $0.03/Share': '[[Dividends]]',
#  'Oppenheimer Reiterates Outperform Rating On Chesapeake Energy': '[[Analyst Rating]]',
#  'Varonis Sees FY19 Adj. EPS $0.04-$0.16 vs $0.32 Estimate, Sales $297M-$305M vs $318.5M Est.': '[[Guidance]]',
#  'Allied Nevada Appoints Director, Corporate Environmental Affairs': '[[Regulatory]]',
#  'InnerWorkings Postpones Annual Shareholder Meeting As Co. In In The Process OF Restating Its Financial Statements': '[[OTHER]]',
#  'XL Insurance and Jorgensen & Company Announce Agreement': '[[Mergers and Acquisitions]]',
#  'Trump Believes Russia Did Not Adhere To Open Skies Treaty': '[[Regulatory]]',
#  'DaVita Q1 Adj. EPS $1.830 Beats $1.470 Estimate, Sales $2.841B Beat $2.800B Estimate': '[[Earnings]]',
#  'Here comes the RBA announcement and statement … due at 0330GMT via ForexLive': '[[OTHER]]',
#  'RTI Surgical Sees FY17 Adj. EPS $0.05-$0.07 vs $0.03 Est.': '[[Guidance]]',
#  "'Department of Energy Announces $40 Million in Funding for 29 Projects to Advance H2@Scale' -Energy.Gov": '[[Regulatory]]',
#  'Novartis Reports Received FDA Approval for Kisqali Femara Co-Pack for Initial Treatment of HR+/HER2- Advanced, Metastatic Breast Cancer': '[[Product Approval]]',
#  'Aurinia Pharma Reports Presentation of Added Data from Phase IIB AURA-LV Study, Showed Stable Renal Function and Blood Pressure without Electrolyte Complications Through 48 Weeks': '[[Products-Services]]',
#  'Paramount Gold Nevada Prices Public Offering of 3.2M Shares At $1.40/Share': '[[Stock price movement]]',
#  'Stocks Which Set New 52-Week Low Yesterday, October 10th': '[[Stock price movement]]',
#  'General Dynamics Land Systems Receives $37.2M Contract to Support Reset of U.S. Marine Corps Light Armored Vehicle Fleet': '[[Products-Services]]',
#  "Dunkin Brands CEO: K-Cups Deal Won't Cannibalize Dunkin' Donuts": '[[Products-Services]]',
#  'Escalade Q3 EPS $0.18 Down From $0.25 YoY, Sales $45.8M Up From $43.955M YoY': '[[Earnings]]',
#  'UPDATE: MaxLinear Sees Q4 Sales ~$99M, Vs. Prior Outlook $95-$100M, Compared to Analyst Consensus Estimate $97M Est.': '[[Guidance]]',
#  'DTE Raises FY18 Operating EPS Guidance From $5.94-$6.32 To $6.12-$6.48 vs $6.16 Estimate': '[[Guidance]]',
#  'Scotiabank Initiates Coverage on Corpbanca at Outperform': '[[Analyst Rating]]',
#  "As Europe Wilts, Don't Eat These BUNS (EWU, EWN, EWP)": '[[OTHER]]',
#  "Deutsche Bank May Have Hired BofA's Jeff Rose - WSJ": '[[Labour Issues]]',
#  'CORRECTION: Goldman Sachs Upgrades Youku Tudou Inc. to Neutral, Maintains $27.00 PT': '[[Price Targets]]',
#  'Option Alert: IGT Oct $17 Call; 6,000 Contract Trade at Ask @$1.15 vs 5,761 OI; Currently $15.85': '[[Stock price movement]]',
#  'Top 4 NYSE Stocks In The Meat Products Industry With The Highest Cash': '[[OTHER]]',
#  'UDF Reports Obtains Further Stay on Nasdaq, Sets Appeal Date': '[[Regulatory]]',
#  "Jefferies Says The 'Transition Continues' At Rackspace": '[[Analyst Rating]]',
#  'MDU Resources Increases Dividend From $0.1925 To $0.1975/Share': '[[Dividends]]',
#  'Wunderlich Initiates Coverage on Atwood Oceanics, Inc. at Hold, Announces $63.00 PT': '[[Price Targets]]',
#  'saving4members Forms Strategic Partnership With MSC Industrial Supply Co For Maintenance, Repair And Operation Costs': '[[Products-Services]]',
#  'UPDATE: JP Morgan Downgrades United Microelectronics on Limited Risk-Reward': '[[Analyst Rating]]',
#  'Mellanox Technologies Q3 EPS $1.33 Beats $1.20 Estimate, Sales $279.211M Beat $275.56M Estimate': '[[Earnings]]',
#  'Janney Capital Upgrades Highwoods Properties to Buy': '[[Analyst Rating]]',
#  'Ron Perelman Praises Technology And Preaches Disruption in Unprecedented Interview': '[[OTHER]]',
#  'Stocks Plunge, But Recover Off Of Lows (SPY, QQQQ, GLD, USO, TLT, UUP)': '[[Stock price movement]]',
#  'Higher One Holdings, Inc. Reports Q1 EPS of $0.20 vs $0.24 Est': '[[Earnings]]',
#  'Taubman Centers Q4 EPS $0.91 Down From $1.03 YoY, Sales $167.49M Miss $172.4M Estimate': '[[Earnings]]',
#  'The Latest Coronavirus Developments From Biotechs: La Jolla Provides Giapreza In Italy, Enanta Researches Antivirals': '[[Products-Services]]',
#  'KeyBanc Downgrades Watts Water Technologies to Sector Weight': '[[Analyst Rating]]',
#  "UPDATE: Credit Suisse Downgrades 2U To Neutral, Lowers Target From $85 To $55 On 'the uncertainty of Domestic Graduate admissions'": '[[Price Targets]]',
#  'UPDATE: Halyard Health Sees Incurring $40M-$50M To Implement ITS Plan': '[[Guidance]]',
#  'Estee Lauder Reports Q4 Adj. EPS $0.43 vs $0.40 Est., Sales $2.65B vs $2.66B Est.': '[[Earnings]]',
#  'Benzinga Pro Morning  Price Check For Sector ETFs: Industrials (VIS) Up 0.6%, Financials (XLF) Up 0.6%, Tech (XLK) Up 0.6%, Energy (XLE) Up 0.5%, Staples (VDC) Up 0.3%, Retail ETF (XRT) Up 0.1%, Utilities (VPU) Down 0.1%': '[[Stock price movement]]',
#  'UPDATE: Vail Resorts Posts Wider FQ4 Loss, Revenue Beats View': '[[Earnings]]',
#  "Benzinga's Top Upgrades, Downgrades For February 22, 2017": '[[OTHER]]',
#  'WD-40 Reports Q EPS of $0.47 vs. $0.53 Est; Revenues $85.5M vs. $87.55M Est\t\t': '[[Earnings]]',
#  'Mad Money Lightning Round: Cramer Likes Buffalo Wild Wings, Alcoa (BWLD, IDCC, IBKR, AA, PNRA, CMG, HCBK, FNFG)': '[[Analyst Rating]]',
#  "Lumos Networks Announces CFO Harold Covert Resigning for 'Family Reasons,' Johan Broekhuysen Named as Interim CFO": '[[Labour Issues]]',
#  'Jefferies Initiates Coverage On SINA with Hold Rating': '[[Analyst Rating]]',
#  'Baird Initiates Coverage On Guidewire Software with Outperform Rating, Announces $143 Price Target': '[[Price Targets]]',
#  'KLR Group Initiates Coverage on Memorial Resource Dev at Buy, Announces $30.00 PT': '[[Price Targets]]',
#  'Commodities Brings Needed Inflation Protection for Vulnerable Retirement Portfolios': '[[OTHER]]',
#  'Jim Cramer Interviews CEO John Riccitiello of Electronic Arts on Mad Money': '[[OTHER]]',
#  'Mid-Afternoon Market Update: AMC Entertainment Drops Amid Q2 Warning; Spirit AeroSystems Shares Surge': '[[Stock price movement]]',
#  'UBS Maintains Buy on Williams Companies, Lowers Price Target to $30': '[[Price Targets]]',
#  'UPDATE: KeyBanc Downgrades Sterling Construction to Hold': '[[Analyst Rating]]',
#  'Benzinga’s Top Pre- Market Losers (LTON, OVTI, LINC, NLST, HGSI, NUVA, AFFX)': '[[Stock price movement]]',
#  'CPI Aerostructures Awarded Multi-Year Contract By Lockheed Martin For F-16V Structural Assemblies': '[[Products-Services]]',
#  'Avon Products Reports Q2 EPS $0.20 vs $0.21 Est; Revenues $2.59B vs $2.66B Est': '[[Earnings]]',
#  'Boeing to Acquire Leading KLX for $4.25B; $63/Share in Cash': '[[Mergers and Acquisitions]]',
#  'UPDATE: Jefferies Initiates Coverage on Targa Resources on Most Attractive Risk/Reward Skew': '[[Analyst Rating]]',
#  'Medivation Reports Q2 EPS $0.58 vs. Est. $0.45, Rev. $174.8M vs. Est. $159.42M': '[[Earnings]]',
#  'KKR, CDPQ Buy USI in Deal Which Values Co. at $4.3B': '[[Mergers and Acquisitions]]',
#  'D.A. Davidson Previews Tyson Foods - Expected Q2 Drop YoY': '[[Guidance]]',
#  'Sypris Reports Q4 EPS $(0.23) vs. $(0.28) YoY, Sales $19.97M vs. $29.12M YoY': '[[Earnings]]',
#  'Barclays Upgrades Sysco Corporation Common Stock to Equal-Weight, Raises to $53.00': '[[Price Targets]]',
#  "Buffett: Corporate Taxes Not 'Strangling' US Competitiveness -CNBC": '[[Regulatory]]',
#  "Acxiom's LiveRamp Acquires Pacific Data Partners to Revolutionize B2B Marketing with People-Based Precision, Terms Not Disclosed": '[[Mergers and Acquisitions]]',
#  "The Market In 5 Minutes: Durable Goods, Benchmark Rate, Tesla's Pickup Truck And More": '[[OTHER]]',
#  'Benzinga Pro Mid-Day Price Check For Regional ETFs: Japan (EWJ) Flat, Brazil (EWZ) Down 0.3%, Europe (VGK) Down 0.4%, Mexico (EWW) Down 0.6%, China ETF (FXI) Down 0.8%, Canada (EWC) Down 0.8%, Australia (EWA) Down 0.9%, Russia (RSX) Down 0.9%': '[[Stock price movement]]',
#  'Urban Outfitters Option Alert: Dec 20 $29 Puts at the Bid: 6000 @ $2.5 vs 10 OI; Earnings 11/18 After Close [est] Ref=$28.17': '[[Stock price movement]]',
#  'Ampco-Pittsburgh Corporation Reports Q3 EPS of $(0.03)': '[[Earnings]]',
#  'Tennant Co. Reaffirms FY17 Sales Outlook, Lowers EPS Range': '[[Guidance]]',
#  "Benzinga's Bulls & Bears Of The Week: Caterpillar, Facebook, Starbucks, Tesla And More": '[[OTHER]]',
#  'Jefferies Reiterating Buy Rating On United Stationers': '[[Analyst Rating]]',
#  'Zacks Industry Outlook Highlights: U.S. Steel Corporation, POSCO, Vale, Rio Tinto and BHP Billiton - Press Releases': '[[OTHER]]',
#  'TD Ameritrade Spokesperson Says No Corporate News to Account for Unusual Option Activity; Monthly Metrics to be Released Second Week of March': '[[OTHER]]',
#  'China XD Plastics Q4 EPS $0.2 Down From $1.02 YoY, Sales $349.826M Down From $427.633M YoY': '[[Earnings]]',
#  "UPDATE: Mizuho On United Health Also Notes Co's 'Revenue Diversification at Optum a Key Differentiator'": '[[Analyst Rating]]',
#  'J.P. Morgan Maintains Underweight on MannKind (MNKD)': '[[Analyst Rating]]',
#  'Best Sector ETFs For October: 3 Stocks Really Matter': '[[OTHER]]',
#  'Top 4 NYSE Stocks In The Business Equipment Industry With The Lowest PEG Ratio': '[[OTHER]]',
#  'Hearing Mosaic Has Laid Off ~368 Workers, 95% of Headcount at Colonsay, Saskatchewan Potash Mine': '[[Labour Issues]]',
#  'Sina Developing Platform for Independent News Bloggers -Marbridge': '[[Products-Services]]',
#  'Louisiana-Pacific Corporation Q3 EPS $0.83 Beats $0.68 Estimate, Sales $736.8M Miss $737.22M Estimate': '[[Earnings]]',
#  'Shares of several software companies are trading higher after Trump administration eased the ban on Huawei after technology stocks tumbled.': '[[Stock price movement]]',
#  'China LED Chip Makers See High Inventory Due to Oversupply': '[[OTHER]]',
#  'Millennial Media Appoints Ross Levinsohn and Tom Evans to Its Board of Directors': '[[Labour Issues]]',
#  'Deutsche Bank Maintains Sell on Cincinnati Financial, Lowers Price Target to $68': '[[Price Targets]]',
#  "Recommends Withdrawal Of Marketing Authorisation For Eli Lilly's Cancer Medicine Lartruvo": '[[Regulatory]]',
#  'MagneGas Forms Subsidiary JV with Confidential Partner': '[[Mergers and Acquisitions]]',
#  'Guidewire Software, Inc. Raises FY2013 EPS Guidance from $0.46-0.47 to $0.50-0.51 vs $0.48 Est': '[[Guidance]]',
#  'Stone Energy Reports Q2 EPS $(0.17) vs. Est. $(0.10), Rev. $149.525M vs. Est. $149.02M': '[[Earnings]]',
#  'Barrington Research Upgrades Surmodics to Outperform': '[[Analyst Rating]]',
#  'Hill-Rom Acquires Welch Allyn For $2.05B In Cash, Stock': '[[Mergers and Acquisitions]]',
#  'CenterPoint Energy Announces Carla Kneipp VP and Treasurer': '[[Labour Issues]]',
#  'Cameco Option Alert: Jul 19 $11 Calls Sweep (13) near the Ask: 5000 @ $0.35 vs 9997 OI; Earnings 7/25 Before Open Ref=$11.12': '[[Stock price movement]]',
#  'US Stock Futures Tumble; Citigroup Earnings In Focus': '[[OTHER]]',
#  'Markets Open Higher; Dollar General Offers $9.7 Billon To Buy Family Dollar': '[[Mergers and Acquisitions]]',
#  'Credit Suisse Downgrades The Hershey to Neutral, Lowers Price Target to $115.00': '[[Price Targets]]',
#  'Chinese FX Reserves Climb Past $3 Trillion, Inflation Concerns Mount (CNY)': '[[Regulatory]]',
#  'Sohu Reports Q3 Loss/Share $(1.94) vs $(2.22) Est; Revenue $410.582M vs $420.03M Est': '[[Earnings]]',
#  'Airlines, Governments And 3PLs Get Creative With Emergency Airlifts': '[[OTHER]]',
#  'Mid-Morning Market Update: Markets Gain; Oracle Shares Fall Following Q3 Results': '[[Stock price movement]]',
#  'Pingtan Marine Enterprise Q3 EPS $0.05 Down From $0.16 YoY, Sales $11.2M Down From $14.685M YoY': '[[Earnings]]',
#  'Hanger, Inc. Sees FY2014 EPS $2.10-2.20 vs $2.17 Est; Sees Sales $1.11B-1.13B vs $1.11B Est': '[[Guidance]]',
#  'Watching Cybersecurity Stocks Tick Slightly Higher To Session Highs Amid News FedEx Experienced Infiltration Of Info System Virus: Proofpoint Shares Up 5% For Session, FireEye Up 3%, Check Point Up 1%': '[[Stock price movement]]',
#  'RealNetworks Reports Q1 EPS $(0.42) Vs Est $(0.38), Sales $28.230M Vs Est $28.64M': '[[Earnings]]',
#  'Engaged Capital Urges Benchmark Electronics Holders to Vote for BLUE Proxy Card': '[[OTHER]]',
#  'LINN Energy Announces $525M Acquisition of Permian Basin Properties ': '[[Mergers and Acquisitions]]',
#  'Intest Holders Holt Family In New Trading Plans -Bloomberg': '[[OTHER]]',
#  'Galena Offers GALE-301 Phase 1/2a Primary Analysis at ASCO': '[[Products-Services]]',
#  'Monster Beverage Board Declares Three-for-One Stock Split': '[[OTHER]]',
#  'DTE Energy Company Narrows FY2014 EPS Guidance from $4.12-4.42 to $4.15-4.39 vs $4.29 Est': '[[Guidance]]',
#  'Citigroup Maintains Buy on Boston Scientific, Lowers Price Target to $40': '[[Price Targets]]',
#  "22nd Century Announces TheImmediate Feasibility Of The FDA's Nicotine Reduction Plan": '[[Regulatory]]',
#  'Smith Micro Announces Tim Huffmyer CFO, Previous CFO Resigned to Pursue Other Interests': '[[Labour Issues]]',
#  'Citigroup Maintains EV Energy Partners at Buy, Raises PT from $66.50 to $72.50': '[[Price Targets]]',
#  'Navistar Partners With GM To Manufacture Cutaway G Van': '[[Products-Services]]',
#  'TiVo Reports EPS of $1.04 May Not Be Comparable to $(0.31) Estimate; Revenues $38.8M vs. $41.98M Estimate\t\t': '[[Earnings]]',
#  'Mizuho Maintains Neutral on ServiceNow, Raises Price Target to $325': '[[Price Targets]]',
#  'CNO Financial Reports $0.29 Vs Est. $0.34, Sales $1.0B Vs Est $971.14M': '[[Earnings]]',
#  "Federal Reserve: Bankers Expressed Views on Counter-Party Credit Limits; Didn't Give Response to Bankers on Stress Test; Voiced Views on Several Points of Dodd-Frank; Said Comments Would be Considered ": '[[Regulatory]]',
#  'Altria Group Reports Q1 EPS $0.49 vs $0.49 Est; Revenues $5.65B May Not Compare vs $4.01B Est': '[[Earnings]]',
#  'Morning Movers for Feb. 26, 2014: ANIK, JAKK, ZAGG, PLUG, TASR, ANF Moving Higher, FST, UTIW, SEAC, FSLR, DWA Lower': '[[Stock price movement]]',
#  'Marathon Petroleum Corporation Provides Interim Second-Quarter 2013 Update ': '[[Guidance]]',
#  'Williams Reports Proposed Offering of 65M Shares Of Common Stock': '[[Stock price movement]]',
#  'NOAA Awards Recent NV5 Acquisition Quantum Spatial $18.8Mllion Shoreline Mapping Contract': '[[Products-Services]]',
#  'DJ Redbook: Reports U.S. Retail Salres First 5 Weeks Down 0.4% MoM, Up 0.6% YoY; Up 1.3% Week End Oct 1 YoY': '[[Stock price movement]]',
#  "Analyst: Investors Should Continue Buying Urban Outfitters After 'Impressive' Q1": '[[Analyst Rating]]',
#  'Financials To Outperform In 2011 (XLF, JPM, BAC, GS, MS, C)': '[[Analyst Rating]]',
#  'Novartis CEO Says Would Potentially Sell Roche Stake Without a Premium, if Opportunity Were Right -Reuters': '[[OTHER]]',
#  "European Commission Approves Two New Regimens Of Merck's KEYTRUDA As First-Line Treatment For Metastatic Or Unresectable Recurrent Head And Neck Squamous Cell Carcinoma": '[[Product Approval]]',
#  'Green Dot Has 24% Upside As It Pivots From Prepaid Market To Full-Fledged Fintech': '[[Analyst Rating]]',
#  "Who's Afraid Of The Big Bad Amazon? VMware Upgraded": '[[Analyst Rating]]',
#  'Carlos Slim Planning to Exercise Warrants in NY Times by End of 2014, Will Keep Shares Following Exercising - Bloomberg': '[[OTHER]]',
#  'ARMOUR Residential REIT Prices 7.75M Share Offering at $7.60 ': '[[Stock price movement]]',
#  'Barclays Maintains Overweight on ServiceNow, Raises Price Target to $185.00': '[[Price Targets]]',
#  'REMINDER: ASH Meeting Begins Tomorrow Dec. 9, Presenters Include Bellicum Pharmaceuticals, Affimed, Cellectis (Pediatric Data for UCART19), and Acceleron Pharma': '[[OTHER]]',
#  'Benzinga’s Top Upgrades (CYMI, SONS, BBBY, AIB, MCK)': '[[Analyst Rating]]',
#  'Putin Says United States Is Not Taking Russian Share On Global Energy Market': '[[Regulatory]]',
#  "'Amazon launches its first big-budget game, a shooter called Crucible' -Tweet From CNBC": '[[Products-Services]]',
#  'SunTrust Robinson Humphrey Upgrades Liberty Prop Trust to Buy': '[[Analyst Rating]]',
#  'Trump On Twitter Says Guatemala Has Decided To Break Safe Third Country Deal; Says He Is Now Looking At Tariffs, Remittance Fees': '[[Regulatory]]',
#  'Pre-Market Imbalance Update: Snap 522K Shares To Sell, BofA 118K To Sell, Alibaba 47K Shares To Buy': '[[Stock price movement]]',
#  'UPDATE: Sterne Agee Upgrades Eagle Materials to Buy on Comfortable Outlook': '[[Analyst Rating]]',
#  'Medassets Down 28% After Missing Earnings Estimates, Citi Downgrades (MDAS)': '[[Stock price movement]]',
#  'Rosetta Resources Announces Temporary Interruption in Production From Eagle Ford Shale in South Texas  ': '[[Products-Services]]',
#  'Eli Lilly And Boehringer Reveals Study On Jardiance For Treatment Heart Failure': '[[Products-Services]]',
#  'July Video Game Sales Down 8% Y/Y (ATVI, ERTS, THQI, TTWO)': '[[Stock price movement]]',
#  'Option Alert: ZIOP Mar16 12.0 Calls: 700 @  ASK  $0.05: 700 traded vs 840 OI:  Earnings today  $8.00 Ref': '[[Earnings]]',
#  'Mid-Morning Market Update: Markets Open Higher; Forest Labs To Acquire Furiex For $1.1B In Cash': '[[Mergers and Acquisitions]]',
#  'Black Rock Affirms it Will Not Acquire More than 4.9% of Common Stock of Level 3': '[[Regulatory]]',
#  'Tesla Shares Spike, Hitting Session High Of $886.6 After Wedbush Note Rumors': '[[Stock price movement]]',
#  "8 Technology Stocks Moving In Friday's Pre-Market Session": '[[Stock price movement]]',
#  'CyberArk Price Target Raised To $45 By Imperial On Impressive Q1, Risk/Reward Balance': '[[Price Targets]]',
#  'SunTrust Robinson Humphrey Downgrades Callon Petroleum to Hold, Lowers Price Target to $1.5': '[[Price Targets]]',
#  'Acacia Subsidiary Enters into Settlement and Patent License Agreement with Kyocera Corporation': '[[Regulatory]]',
#  'Form 8-K from Wesco Shows Co. Boosted Purchase Limit Under Receivables Facility from $475M to $500M, Can Increase Limit Added $100M': '[[Regulatory]]',
#  'Citigroup Maintains Buy on Travelers Companies, Raises Price Target to $149': '[[Price Targets]]',
#  'UPDATE: NovellusDx Shareholders Will Receive Stock Equal To ~49% Of Equity Of Cancer Genetics': '[[Mergers and Acquisitions]]',
#  "John McAfee's Shocking Plunge Back into the Public Eye": '[[OTHER]]',
#  "Eros Int'l Shares Saw Late-Day ~$0.35 Tick Lower Following Filing Showing $350M Mixed Securities Shelf Offering": '[[Stock price movement]]',
#  'UPDATE: Barclays Initiates Coverage on Activision Blizzard on Multiple Positive Factors': '[[Analyst Rating]]',
#  'Cornerstone Real Estate Advisers To Acquire ACRE Capital Holdings LLC For $93M': '[[Mergers and Acquisitions]]',
#  'Lightbridge Corporation Reports Q3 EPS of $(0.11); Revenue of $169.15K': '[[Earnings]]',
#  'WHO Head Tedros Highlights Number Of Cases In China Continues To Decline': '[[OTHER]]',
#  'Morgan Stanley Upgrades Northern Trust to Equal-Weight, Announces $92 Price Target': '[[Price Targets]]',
#  'Medtronic Reports Q2 EPS $0.84 vs $0.82 Est; Revenues $4.13B vs $4.07B Est\t\t\t ': '[[Earnings]]',
#  'B. Riley Initiates Coverage on Reading International at Buy': '[[Analyst Rating]]',
#  'Shares of several Brazilian companies are trading lower with the broader Brazilian equities market.': '[[Stock price movement]]',
#  'Current Top Percentage Gainers And Losers (XNPT, DGW, IMGN, TPCG, DBLE, GSK, QXM, QTWW, RT, SUPG, NLST)': '[[Stock price movement]]',
#  'Points International Q2 EPS $0.45 May Not Compare To $0.13 Estimate, Sales $100.23M Beat $89.15M Estimate': '[[Earnings]]',
#  'CACI International Awarded Multi-Million Contract From U.S. Army For Electronic Warfare': '[[Products-Services]]',
#  'Hecla Mining shares are trading lower after the company reported worse-than-expected Q2 EPS and sales results.': '[[Earnings]]',
#  'Macquarie Initiates Coverage on Nielsen Holdings at Outperform, Announces $61.00 PT': '[[Price Targets]]',
#  '8-K from Key Tech Shows Co. Incurred Restructuring Charges Related to Personnel Expenses, Sees Pre-Tax Charges ~$580K': '[[Labour Issues]]',
#  'Boeing, Air Lease Corporation Sign Order for Eight 737 MAX Airplanes Valued At $936.8M': '[[Products-Services]]',
#  'FDA Issues Warning Letter to ConAgra, Related to Listeria Following Plant Inspection': '[[Regulatory]]',
#  "15 Industrial Stocks Moving In Monday's Pre-Market Session": '[[Stock price movement]]',
#  'ANF Shareholder Engaged Capital Retains Advisors to Aid in Efforts to Set New Direction for Co': '[[OTHER]]',
#  "Wedbush's Pachter Neutral On LinkedIn But 'Cautiously Optimistic Q3 Kicked Off A Trend'": '[[Analyst Rating]]',
#  'Can Lennar Post Low-Teens EPS Growth? Experts & Crowd Disagree': '[[Guidance]]',
#  'Arista Networks Stock Already Reflects Bright Growth Prospects, Morgan Stanley Says In Downgrade': '[[Analyst Rating]]',
#  'Magellan Midstream Option Alert: Jan 19 $70 Calls Sweep (2) at the Bid: 1200 @ $0.651 vs 6894 OI; Ref=$68.06': '[[Stock price movement]]',
#  'Crude Oil Breaks The Dollar Rule For The Summer High Noon': '[[OTHER]]',
#  'ExxonMobil to Acquire 25% Interest in Mozambique Area 4 from Eni for ~$2.8B': '[[Mergers and Acquisitions]]',
#  'Molson Coors CEO: Ice Tea-Flavored Brew Will Unlock Sales': '[[Products-Services]]',
#  'Raymond James Downgraded Frontier Communications from Outperform to Market Perform': '[[Analyst Rating]]',
#  'First Merchants Corporation and MBT Financial Corporation To Merge In $290.9M Transaction': '[[Mergers and Acquisitions]]',
#  'Shares of several Chinese companies are trading lower due to continued uncertainty about the future of trade between the US and China.': '[[Stock price movement]]',
#  'Carmike and AMC Amend Merger Agreement, Carmike Shareholders Can Get $33.06 Cash or 1.0819 AMC Shares': '[[Mergers and Acquisitions]]',
#  '11 Best Labor Day 2014 Car Sales You Should Know About': '[[OTHER]]',
#  'Applied Genetic Technologies shares are trading lower after the company announced a proposed public offering of common stock of 6 million shares.': '[[Stock price movement]]',
#  'Janney Capital Downgrades bebe stores, inc. to Neutral': '[[Analyst Rating]]',
#  'Callon Petroleum Company Announces Increase in Borrowing Base to $30M  ': '[[Credit Ratings]]',
#  'ReneSola Q2 EPS $0.00 Misses $0.03 Est. Sales $27.809M Beat $25.5M Estimate': '[[Earnings]]',
#  'Mid-Afternoon Market Update: Dow Slides Over 300 Points; Otonomy Shares Tumble Following Public Offering Of Stock': '[[Stock price movement]]',
#  'Trump Says Not In Favor Of Reopening China Trade Deal': '[[Regulatory]]',
#  "Sterne Agee On Whole Foods: 'When You Don't Know The Bottom, It's Hard To Step In And Buy The Stock'": '[[Analyst Rating]]',
#  'TransCanada Sends Letter to U.S. Department of State on Keystone XL': '[[Regulatory]]',
#  'Credit Suisse Upgrades Phillips 66 Partners to Outperform': '[[Analyst Rating]]',
#  'Option Alert: $NMBL Nov $25 Call; 4489 contracts @Ask @$0.65; Now $23.01': '[[Stock price movement]]',
#  'DaVita HealthCare Partners Reports Q1 Adj. EPS $0.86, Inline, Sales $3.287B vs $3.25B Est.': '[[Earnings]]',
#  'Hearing Gabelli Saying Appointment Of Mr. McCollum Increases Likelihood Halliburton Will Acquire WFT Down The Road': '[[OTHER]]',
#  'Gannett In Advanced Talks To Merge With GateHouse, Deal Could Be Announced In Next Few Weeks': '[[Mergers and Acquisitions]]',
#  'Roth Capital Previews Q2 Earnings for Solar Group: Holds Long Bias for Overall Sector, Highlights Top Picks Canadian Solar, Solarcity, Hannon, Solaredge': '[[Analyst Rating]]',
#  'SkyWest Adds 8 Embraer E175s to Fleet, Replacing 8 Older Regional Jets for Alaska Airlines Flying': '[[Products-Services]]',
#  'Disney Partners With Vera Bradley To Launch New Merchandise': '[[Products-Services]]',
#  'The Market In 5 Minutes: CSX CEO, Overstock, Net Neutrality, Amazon Prime, And More': '[[OTHER]]',
#  'Quad/Graphics Reports Purchase Of Apple Tree Group, No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  'BTIG Assumes Proofpoint at Buy, Announces $125 Price Target': '[[Price Targets]]',
#  'Fast Money Halftime Recommendations (OXY, CVX, ABT, PFE, MRK, AXP, C, BAC, JPM)': '[[OTHER]]',
#  'Clovis Oncology Shares Now Up 6% Following Chatroom Chatter': '[[Stock price movement]]',
#  'Intellipharmaceutics Reports Launch of Generic Seroquel XR by Mallinckrodt': '[[Products-Services]]',
#  'VMWare Guides FY12 Revenue $4.54-4.64B vs $4.59B Est; Guides Q3 Revenue $1.11-1.15B vs $1.14B Est': '[[Guidance]]',
#  "Hearing McDonald's Has Partnered With Doordash To Expand US Delivery Sales": '[[Products-Services]]',
#  'La-Z-Boy shares spike 11.3% after hours following strong Q1 earnings': '[[Stock price movement]]',
#  'Nomura Instinet Maintains Neutral on Criteo, Raises Price Target to $11': '[[Price Targets]]',
#  'Comtech Telecomms Q2 Adj. EPS $0.40 May Not Compare To $0.16 Estimate, Sales $164.1M Beat $159.96M Estimate': '[[Earnings]]',
#  'Oxford Lane Capital to Terminate and Repay its $40M Repurchase Agreement with Nomura Securities': '[[Regulatory]]',
#  'Bank of America Maintains Buy on Health Net Inc., Raises PT to $61.00': '[[Price Targets]]',
#  'Shares of Baker Hughes Resume; Bounce Into Positive Territory, Now Up ~3% to $48.07': '[[Stock price movement]]',
#  'La-Z-Boy CEO In Earnings Release Says Co. Plants Will Shut Down For One Week Of Vacation & Maintenance In July During Q1 (As Is Typical), Q1 Is "Usually the company\'s weakest in sales and earnings"': '[[Guidance]]',
#  '10-Q: Morgan Stanley Discloses Illinois AG Demanding $88M; Alleges RMBS Misrepresentations': '[[Regulatory]]',
#  'Morgan Stanley Upgrades ABB Ltd Common Stock to Overweight': '[[Analyst Rating]]',
#  'Mid-Morning Market Update: Markets Rise; Allergan To Acquire Kythera Biopharmaceuticals For $2.1B': '[[Mergers and Acquisitions]]',
#  'UPDATE: Goldman Sachs Raises PT to $4.40 on Brocade Communications Systems; Solid FQ2  ': '[[Price Targets]]',
#  'Keystone XL Pipeline Hits Another Snag As Judge Cancels Critical Permit': '[[Regulatory]]',
#  'Jim Cramer Shares His Thoughts On Visa, UPS, FedEx And Southern Co': '[[OTHER]]',
#  'Option Alert: HTZ Dec16 11.0 Calls Sweep: 875 @  ASK  $0.80: 875 traded vs 67 OI: $8.56 Ref': '[[Stock price movement]]',
#  'Option Alert: Microchip Tech Apr 70.0 Calls: 650 @  ASK  $2.35: 655 traded vs 527 OI:  Earnings 2/7 After Close  $68.56 Ref': '[[Stock price movement]]',
#  "Jim Cramer Says Joy Global's Buyout Is A 'Remarkable Deal'": '[[OTHER]]',
#  'Dreamworks Animation SKG (DWA) Climbs After Upgrade To Overweight': '[[Analyst Rating]]',
#  'Oppenheimer Reiterates Outperform on Allscripts Healthcare Solutions': '[[Analyst Rating]]',
#  'Wells Fargo Downgrades Castlight Health to Underweight, Lowers Price Target to $1.2': '[[Price Targets]]',
#  'Morgan Stanley Maintains Equal-Weight on FactSet Research Systems, Raises Price Target to $264': '[[Price Targets]]',
#  'Apple and Boeing Earnings, Plus Oil Drag, Combine To Dent Stocks': '[[Stock price movement]]',
#  'UPDATE: ISI Group Downgrades AmerisourceBergen to Neutral Following WAG Deal': '[[Analyst Rating]]',
#  'Wedbush Securities Maintains Pier 1 Imports at Outperform, Raises PT from $21 to $22': '[[Price Targets]]',
#  'Innate Pharma Announces  AstraZeneca to Advance Monalizumab to Phase III in Head and Neck Cancer': '[[Products-Services]]',
#  "PacCrest Analyst Sees Early Checks In Adobe 'Encouraging'": '[[Analyst Rating]]',
#  'Top Performing Industries For December 2 (WBD, CRH, LOW, SMS)': '[[Stock price movement]]',
#  "UPDATE: Germany's Schaeuble Says Euro Nations Solving Problems Step by Step, Ireland and Portugal Doing a Good Job; Commission Must Support Greece More Efficiently; Firewall Useless if Problems Remain Unsolved": '[[Regulatory]]',
#  "White House Says FAA Proposal Is 'Critical Step To Safely Integrate Commercial Drones Into The National Airspace'": '[[Regulatory]]',
#  "Top 10 Most Overbought Stocks Via Benzinga Pro's Radar Tool For Wed., June 19, 2019": '[[Stock price movement]]',
#  'Mad Money Lightning Round: Cramer Advises Investors To Buy Peabody Energy (COP, ARG, MOS, POT, DTG, MLNX, RVBD, ONNN, DE, BTU)': '[[Analyst Rating]]',
#  "UPDATE: Jos. A. Bank Says talks of Possible Boosted Bid for Men's Wearhouse Following Results of Due Dilligence": '[[Mergers and Acquisitions]]',
#  'NASDAQ Turns Positive For The Year On An Intraday Basis': '[[Stock price movement]]',
#  'Towerstream Reports Record Number of Contracts from Nov': '[[Products-Services]]',
#  'Pre-Market Top Percentage Gainers and Losers (XNPT, GSK, ZAGG, LOGI, BBBY, PRXL, BLUD, INHX, PWER, INTC, TZOO, KERX) ': '[[Stock price movement]]',
#  'BGB Securities Upgrades TD Ameritrade Holding from Sell to Hold': '[[Analyst Rating]]',
#  "BlackBerry's Good Technology Acquisition Is 'Positive' For Company, JP Morgan Says": '[[Analyst Rating]]',
#  'Option Alert: NRG Mar 18.0 Calls: 10000 @  ASK  $0.95: 19k traded vs 247 OI:  Earnings 2/28 Before Open  $17.25 Ref': '[[Stock price movement]]',
#  'Deutsche Bank Initiates Coverage On Landstar System, Inc. - Common Stock at Buy, Announces $82.00': '[[Price Targets]]',
#  'Option Alert: ANF Nov16 14.0 Puts Sweep: 630 @  ASK  $0.38: 3105 traded vs 5595 OI:  Earnings 11/18 Before Open  $15.69 Ref': '[[Stock price movement]]',
#  'USA EIA Natural Gas Inventories for Apr 24 Build 70 bcf vs Build 69 bcf Est; Prior Build 43 bcf': '[[OTHER]]',
#  'Intel Starts Off Earnings Season For Chip-Maker Group With A Thud': '[[Earnings]]',
#  'Stereotaxis Announces Positive Results from First 50 Clinical Procedures Performed with New Niobe ES™ System ': '[[Products-Services]]',
#  'Metals Higher This Morning, Led By Copper (SLV, GLD, JJC, PALL, PLTM)': '[[Stock price movement]]',
#  'US Ecology Reports Q2 EPS $0.39 vs $0.22 Est; Revenues $40M vs $36.35M Est': '[[Earnings]]',
#  '8-K from EA Shows Chairman Lawrence Probst III to Step Down, Will Continue as Non-Exec Chair': '[[Labour Issues]]',
#  "WBI Shares' New Fund Chases Bulls Via Tactical Reallocation, Investing In Other ETFs": '[[Products-Services]]',
#  'Nustar GP Holdings Chairman Greehey Buys 70,097 Shares @$33.57/Share -Form 4': '[[OTHER]]',
#  'ACI Worldwide Extends Timing Agreement With the DOJ for an Additional Ten Days; Extends Expiration Date for S1 Exchange Offer ': '[[Regulatory]]',
#  'First Midwest Bancorp Reports Purchase Of Northern Oak Wealth Mgmt., No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  '10 Of The Most Crowded Trades, And 10 Of The Least Crowded': '[[OTHER]]',
#  'Energy Investor Alert: Osage and PetroQuest Announce Mississippian Formation Acreage Acquisitions': '[[Mergers and Acquisitions]]',
#  'Before Syria Blowup, Short Interest In Defense Stocks Shrank (GD, HII, UTX)': '[[Stock price movement]]',
#  'UPDATE: ChemoCentryx, Vifor Entered Amendment To Collaboration, License Deal To Account For Exclusive License To Commericialize CCX140 In Certain Countries Outside US, Vifor To Pay ~$11.5M': '[[Products-Services]]',
#  'TD Ameritrade Spokesperson Confirms Was Victim of New Hacking Indictment Against Gery Shalon': '[[OTHER]]',
#  "NASDAQ Says Tarena Int'l 'to Open for Trading Shortly,' Remains in Pre-Launch Price Discovery": '[[Stock price movement]]',
#  "Massad: 'We Didn't Think We Could Get this Far this Fast'": '[[OTHER]]',
#  "Jiayuan.com Special Committee Engages Financial Advisor and Legal Counsel to Assist in Review of 'Going Private' Offer": '[[Mergers and Acquisitions]]',
#  'Perrigo Reaffirms FY19 Adj. EPS $3.75-$4.05 vs $3.93 Estimate': '[[Guidance]]',
#  'IDEX Corporation Announces Plans to Delist from Chicago Stock Exchange, Will Continue Listing Of Common Stock On NYSE': '[[Regulatory]]',
#  'Sonoco Reports 10% Price Increase on All EPS Parts, Components, 7% Increase on All Sonopost Products': '[[Products-Services]]',
#  '8-K From Progenics Pharma Reports On May 25th Co. Entered a Settlement With Valeant and Salix Regarding Patent Infringement Case': '[[Regulatory]]',
#  '10 Industries That Could Be Impacted by Driverless Cars': '[[OTHER]]',
#  'Keep an Eye on These 5 Stocks for November 11, 2015': '[[OTHER]]',
#  'Mitel Views Mavenir Purchase Modestly Dilutive In Second Half Of 2015': '[[Guidance]]',
#  'Carriage Services Reports Q2 EPS $0.37 vs. Est. $0.39, Rev. $61.9M vs. Est. $61.34M': '[[Earnings]]',
#  'Horsehead holding Corporation Reports Q1 EPS $0.05 vs $0.09 Est; Revenues $111.4M vs $112.92M Est': '[[Earnings]]',
#  'Raymond James Maintains Strong Buy on Meta Financial Group, Raises Price Target to $41': '[[Price Targets]]',
#  'Citigroup Downgrades Citizens Financial Group, Inc. Common Stock to Neutral': '[[Analyst Rating]]',
#  "13F From Einhorn's Greenlight Shows Liquidated Stakes In Chemours, Dillard's, Shutterfly": '[[OTHER]]',
#  'Credit Suisse Upgrades Antero Midstream Partners to Outperform, Raises PT to $34.00': '[[Price Targets]]',
#  'Pacific Premier Bancorp Q4 EPS $0.69 Beats $0.61 Estimate': '[[Earnings]]',
#  'AbbVie And Morphic Therapeutic Announce Collaboration Targeting Fibrotic Diseases': '[[Products-Services]]',
#  'Black Box Raises Qtr. Dividend from $0.11 to $0.12/Share': '[[Dividends]]',
#  'Argus Research Initiates Coverage on Cummins Inc. at Buy, Announces $162.00 PT': '[[Price Targets]]',
#  'BlackBerry And CEO John Chen Agree to Contract Extension Through Nov. 2023': '[[Labour Issues]]',
#  'Stamps.com Cuts FY19 Adj. EPS Guidance From $5.15-$6.15 To $3.35-$4.85 vs $5.43 Est.': '[[Guidance]]',
#  'Internap Q3 EPS $(1.01) Misses $(0.76) Estimate, Sales $72.878M Miss $73.34M Estimate': '[[Earnings]]',
#  'Wilhelmina Reports Q3 Adj. EBITDA $834K vs $1.46M in Same Qtr. Last Year, Sales $20.9M': '[[Earnings]]',
#  'KBC Securities Downgrades Prosensa to Hold, Raises PT to $19.80': '[[Price Targets]]',
#  "Time Warner Cable-Comcast Marriage Failed; What's Next?": '[[Mergers and Acquisitions]]',
#  'ResMed shares are trading higher after the company reported better-than-expected Q4 EPS and sales results. The company also raised its quarterly dividend.': '[[Earnings]]',
#  '3M Reports Q4 EPS $1.35 vs $1.31 Est; Revenues $7.1B vs $7.09B Est\t\t\t\t\t ': '[[Earnings]]',
#  "'Elon Musk's Boring Company completes excavation of Las Vegas' electric 'Loop'' -Electrek": '[[Products-Services]]',
#  'UPDATE: Piper Jaffray Upgrades Pacific Sunwear of California to Overweight Following Teen Survey': '[[Analyst Rating]]',
#  'Cliffs Natural Resources Inc. Reports Q1 EPS of $0.66, Down 22% YOY; Revenue of $1.14B vs $1.19B Est': '[[Earnings]]',
#  'IMAX Reports Deal for Three New Theatres in South Africa': '[[Products-Services]]',
#  'Sears Not Having a Happy Holidays, Home Depot to Benefit?': '[[OTHER]]',
#  'The Container Store Sees FY18 Sales At Lower End Of Previously-Issued $885M-$895M Range, Adj. EPS At Low End To Slightly Below $0.41-$0.51 Range': '[[Guidance]]',
#  'THL Credit Announces Public Offering Of 6.6 Million Shares': '[[Stock price movement]]',
#  'Quicklogic Q4 Adj. EPS $(0.04), Inline, Sales $2.8M Miss $3M Estimate': '[[Earnings]]',
#  'Company News for August 5, 2010 - Corporate Summary': '[[OTHER]]',
#  'Russians in New York: Major NYSE-Traded Russian Companies (MTL, MBT, VIP, WBD)': '[[OTHER]]',
#  'Westar Energy, Wisconsin Energy, Exelon Shares Tumble to Session Lows Following Mid-Day Downgrades from Edward Jones': '[[Analyst Rating]]',
#  "Shares of Kite Pharma Rise as Much as 54% After-Hours Monday on Positive Non-Hodgkin's Lymphoma Trial Results Using KTE-C19": '[[Products-Services]]',
#  "Wendy's Arby's Group Ticking Higher On Renewed Takeover Chatter (WEN)": '[[Stock price movement]]',
#  'Option Alert: Sproutts FM Jul 20.0 Calls: 1000 @  ASK  $1.10: 1173 traded vs 5 OI:  Earnings 8/3 Before Open (est)  $19.91 Ref': '[[OTHER]]',
#  'PAX Labs, Inc. Announces Fashion Retail Partnership With Notre Shop Chicago': '[[Products-Services]]',
#  "CEL-SCI Wins Approval from Gov't of Crotia to Begin Phase III Trial for Multikine in Head, Neck Cancer": '[[Product Approval]]',
#  'Western Union To Launch Remittance Services Into Cuba By Q2 2016': '[[Products-Services]]',
#  'Benzinga Pro Mid-Day Price Check For Sector ETFs: Staples (XLP) Up 0.3%, Energy (XLE) Up 0.3%, Utilities (XLU) Up 0.2%, Industrial (XLI) Up 0.2%, Materials (XLB) Up 0.2%, Communications (XLC) Down 0.3%': '[[Stock price movement]]',
#  'J.P. Morgan Leaves Gilead Sciences Overweight Rating, $45 PT Unchanged (GILD)': '[[Price Targets]]',
#  'Option Alert: Davita Healthcare: January 130 Call; Block Trade: 1,600 Contracts @$2.10; Currently $113.62': '[[Stock price movement]]',
#  'SINA Earlier Said Expecting FY18 Sales $2.23B-$2.38B vs $2.15B Est.': '[[Guidance]]',
#  'Tyson Reports Purchase of AdvancePierre Foods for $40.25/Share in Cash, Total Enterprise Value ~$4.2B': '[[Mergers and Acquisitions]]',
#  "Peak Resorts Says 'the Board doesn't believe that it is prudent to consider the issuance of a dividend while the EB-5 funds remain in escrow.'": '[[Dividends]]',
#  'UPDATE: Height Securities Raises Odds Individual Healthcare Mandate Repeal Remains In Final Tax Bill To 75%, Calls This Tailwind For Short-Term Medical Insureres (e.g. JP, IHC, HIIQ, EHTH), Minor Headwind For Managed Care And Hospitals (e.g. CNC, MOH)': '[[Analyst Rating]]',
#  'Top Semiconductors Stock Picks to buy on 5/6/11- KLIC, DIOD, SPRD, NPTN, PSEM, SQNS, NVLS, ONNN, FSII, AUTH, NVMI, SIMO': '[[OTHER]]',
#  'Shares of several industrial companies are trading higher as equities gain strength on news that some U.S. states will reopen their economies in phases, increasing economic activity and optimism around the coronavirus pandemic.': '[[Stock price movement]]',
#  'UPDATE: Goldman Sachs Reiterates Neutral Rating, Lowers PT for Navistar International': '[[Price Targets]]',
#  'Energy Fuels Receives EPA Approval for Future Expansion of Nichols Ranch Uranium Project': '[[Product Approval]]',
#  'Shares of several semiconductor companies are trading higher after President Trump made positive remarks on the U.S.-China trade talks. Trump is scheduled to meet with Chinese Vice Premier Liu He at the White House today.': '[[Stock price movement]]',
#  'Financial Breakfast: Morning News Summary for July 18, 2012': '[[OTHER]]',
#  "UBS Maintains Buy on Lowe's Companies, Raises Price Target to $130": '[[Price Targets]]',
#  'Delphi Technologies Q2 Adj. EPS $0.58 Misses $0.61 Estimate, Sales $1.121B Miss $1.14B Estimate': '[[Earnings]]',
#  'Deutsche Bank Reiterates Buy, Lowers PT On Five Below On Lower Revised Estimates': '[[Price Targets]]',
#  'National CineMedia Files to Sell up 56.9M Shares of Common Stock': '[[Stock price movement]]',
#  'Marlin Business Services Corp. Reports Q1 Adj. EPS $0.34 vs $0.36 Est.': '[[Earnings]]',
#  'Innospec Inc. Reports Q3 EPS of $0.77 vs $0.75 Est; Revenue of $228.20M vs $228.40M Est': '[[Earnings]]',
#  'Assured Guaranty (AGO) Shares Rise As Q4 Results Defy Analysts’ Expectations ': '[[Earnings]]',
#  'A Bittersweet Day For Democracy: Brazil President Dilma Rousseff Impeached': '[[OTHER]]',
#  'Benzinga Pro Afternoon Price Check For Sector ETFs: Utilities (VPU) Down 0.5%, Financials (XLF) Down 1.0%, Retail ETF (XRT) Down 1.4%, Industrials (VIS) Down 1.6%, Staples (VDC) Down 1.8%, Tech (XLK) Down 2.3%, Energy (XLE) Down 2.4%': '[[Stock price movement]]',
#  'CIBC to Buy Atlantic Trust Private Wealth Mgmt from Invesco for $210M': '[[Mergers and Acquisitions]]',
#  'Vectren Reports Q2 EPS $0.18 vs $0.12 Est              ': '[[Earnings]]',
#  'UPDATE: Dahlman Rose Upgrades Thompson Creek Metals to Buy on Commodity Price Bounce  ': '[[Analyst Rating]]',
#  'American Homes 4 Rent Earlier Reported Bryan Smith As COO': '[[Labour Issues]]',
#  'Omnicom Announces Randall Weisenburger Steps Down As CFO': '[[Labour Issues]]',
#  'ISS Endorses Western Digital-SanDisk Merger: What It Means For Shareholders': '[[Mergers and Acquisitions]]',
#  'Citigroup Initiates Coverage on Versartis, Inc. at Buy, Announces $60.00 PT': '[[Price Targets]]',
#  'Activision Publishing Files Patent Infringement Suit against Worlds Inc., Worlds Online': '[[Regulatory]]',
#  'TransAlta Reports Q4 EPS C$0.18 vs. $0.11 Est., Funds From Operations of C$0.79': '[[Earnings]]',
#  'LEDinside Says Decreasing LED Bulb Price Trend to Continue in 2014 -Digitimes': '[[OTHER]]',
#  'Cryolife Q1 EPS $0.04, Inline, Sales $67.5M Beat $66.36M Estimate': '[[Earnings]]',
#  'Seeing Notable Block Trade In Encana; 1M Shares At $10.09': '[[Stock price movement]]',
#  'Goldman Sachs Is Making Waves In The Pipeline Space': '[[OTHER]]',
#  "SunTrust's Bob Peck Says 'Remain on Sidelines' With AOL": '[[Analyst Rating]]',
#  'Home Depot Shares Rise 3% Premarket on Strong Earnings Beat, Dividend Increase, Share Buyback Announcement': '[[Stock price movement]]',
#  'UPDATE: Genuine Parts Q1 Automotive Group Sales Flat at $1.9B': '[[Earnings]]',
#  'RBC Capital Upgrades Altera Corporation to Outperform, Raises PT to $39.00': '[[Price Targets]]',
#  'Another Day, Another Bank Misses On Earnings: Market Could Be On Defensive': '[[OTHER]]',
#  'Goldman Sachs Initiates Coverage on Darden Restaurants at Neutral, Announces $74.00 PT': '[[Price Targets]]',
#  'Hawaiian Airlines Reports November Load Factor Decreased 1.8 Points To 84.1%': '[[OTHER]]',
#  'Benzinga Pro Morning Price Check For Sector ETFs: Staples (VDC) Up 0.8%, Financials (XLF) Up 0.6%, Energy (XLE) Up 0.5%, Utilities (VPU) Up 0.4%, Tech (XLK) Up 0.1%, Retail ETF (XRT) Down 0.2%, Industrials (VIS) Down 0.3%': '[[Stock price movement]]',
#  'Citigroup Maintains Buy on American Axle & Mfg Hldgs, Lowers Price Target to $6': '[[Price Targets]]',
#  '3G Capital May be Targeting Deals for Pepsi, Campbell Soup -Wall Street Journal': '[[Mergers and Acquisitions]]',
#  'Aurora Launches Development of Optionally Piloted Vehicle Based on the DA42M': '[[Products-Services]]',
#  'The Biotech Stock With The Best One-Week Performance': '[[Stock price movement]]',
#  'Jobless Claims Up, But Trend Still Down - Analyst Blog': '[[OTHER]]',
#  "Cablevision-Altice Is Finally Happening; What's Next?": '[[Mergers and Acquisitions]]',
#  'Sony PlayStation OLED Vita Launches In Japan, Could be Positive for Universal Display': '[[Products-Services]]',
#  'Gevo Sells off to Low of $0.52 following Offering Announcement': '[[Stock price movement]]',
#  'Jim Cramer Shares His Thoughts On Waste Management, Deere And NXP Semiconductors': '[[OTHER]]',
#  'Option Alert: Delphi Automotive November 32.5 Call; Block Trade: 14,779 Contracts; Currently $29.62': '[[Stock price movement]]',
#  'Oncolytics Biotech Announces Encouraging Data from REO 018 Randomized Study of REOLYSIN in Head and Neck Cancers ': '[[Products-Services]]',
#  'Editor of Little Bear Blog Says Time to Begin Covering Oracle Short Here': '[[Analyst Rating]]',
#  'Drilling Stocks Unaffected Following Word Of Trump Admin. Proposed New Rules For Off-Shore Area Drilling': '[[Regulatory]]',
#  'Lavazza Reports 6.8% Stake in Green Mountain Coffee': '[[Mergers and Acquisitions]]',
#  'Dermalogica Selects 8x8 X Series With Contact Centre to Power its Customer Service Experience in UK and Ireland': '[[Products-Services]]',
#  'Morgan Stanley Initiates Coverage on Third Point Reinsurance at Overweight, Announces $16.50 PT': '[[Price Targets]]',
#  'Neptune Completes Submission To FDA For Registration Of Conover, NC Facility For Production Of Hand Sanitizers': '[[Product Approval]]',
#  'Retail Economist/Goldman Sachs Chain Store Sales Down 0.8% In Nov 10 Week, Up 1.8% Year Over Year': '[[Stock price movement]]',
#  'BZ NOTE: Reminder Kraft Spun Off Mondelez in Mid 2012': '[[OTHER]]',
#  "Barron's Picks And Pans: Coronavirus Picks, Bonds, Safe Havens And More": '[[OTHER]]',
#  'Time Warner Cable Loses Challenge to FCC Carriage Regulation': '[[Regulatory]]',
#  'Cantor Fitzgerald Initiates Coverage on Post Properties at Buy, Announces PT of $50': '[[Price Targets]]',
#  'TiVo Option Alert: Oct 18 $7 Calls Sweep (13) near the Ask: 3000 @ $2.601 vs 2265 OI; Earnings 5/9 After Close [est] Ref=$9.32': '[[Stock price movement]]',
#  'Black Box Shares Now Trading Up 100% For The Session After Co. Earlier Announced Data Center Contract With Social Media Company': '[[Products-Services]]',
#  'UPDATE: US Senator Nelson Asks Three Federal Agencies to Investigate Lumber Liquidators -Reuters': '[[Regulatory]]',
#  'Citigroup Maintains Neutral on T. Rowe Price Group, Raises Price Target to $135': '[[Price Targets]]',
#  'Tech Expert: Own GoPro Before It Starts Selling Drones': '[[OTHER]]',
#  'Oppenheimer Reiterating Outperform On Tesoro Logistics Partners ': '[[Analyst Rating]]',
#  'Bristol-Myers Squibb Reports FDA Approval of US Product Labeling Update for Sprycel, Will Include Five-Year First-Line, Sever-Year Second-Line Efficacy, Safety Data': '[[Product Approval]]',
#  "Lowe's Misses Expectations On Q1 Earnings, Blames Unseasonably Cool Weather ": '[[Earnings]]',
#  'UPDATE: ISI Group Upgrades Fortune Brands Home & Security to Buy on Earnings Acceleration  ': '[[Analyst Rating]]',
#  'Deutsche Bank Maintains Buy on Magellan Health Services, Inc., Raises PT to $53.00': '[[Price Targets]]',
#  'Iamgold shares are trading lower after the company reported Q1 financial results and the stock was downgraded by Canaccord Genuity from Buy to Hold.': '[[Stock price movement]]',
#  'Goldman Sachs Maintains Buy, $84 PT on Camden Property Trust ': '[[Price Targets]]',
#  '13F From Omega Shows Increased Stake In Sinclair Broadcast Group; Exited Stake In Tribune Media, Walgreens Boots Alliance and Weatherford International': '[[OTHER]]',
#  'Five Prime Therapeutics Filing Shows Registration For $250M Common Stock Offering': '[[Stock price movement]]',
#  'Itron Q1 Adj. EPS $0.7 Beats $0.44 Estimate, Sales $614.576M Beat $585.65M Estimate': '[[Earnings]]',
#  'Nomura Downgrades DineEquity to Neutral, Lowers price target to $77.00': '[[Price Targets]]',
#  'Horace Mann Educators Reports Q4 EPS $0.72 vs $0.53 Est; Revenues $247.6M vs $243.18M Est\t\t ': '[[Earnings]]',
#  'Hearing FCC Has Denied Motion For Extension, Added Info In Sinclair/Tribune Deal': '[[Regulatory]]',
#  'Barclays Raises Target On Chipotle, Sees Buffalo Wild WIngs Q2 Beat': '[[Price Targets]]',
#  'Keefe Bruyette & Woods Initiates Coverage On Fidelity National Info with Outperform Rating, Announces $136 Price Target': '[[Price Targets]]',
#  'Priceline.com Prices $1B in Convertible Senior Notes Offering': '[[Stock price movement]]',
#  'Keefe, Bruyette & Woods Upgrades Dynex Capital to Outperform, Raises Price Target to $17.5': '[[Price Targets]]',
#  "BTIG Previews Workday's Q2 Results, Comments On IBM Deal": '[[OTHER]]',
#  'Spectrum Brands Holdings To Reaffirm Fiscal 2020 Guidance At CAGNY Conference; Sees FY20 Adj. EBITDA $570M-$590M, Adj. FCF $240M-$260M': '[[Guidance]]',
#  'Top Day Trader Alerts (BIDU, BSMD, ERTS, HAUP, JCP, NBG, NVDA, BEE, YHOO)': '[[OTHER]]',
#  'Stifel Nicolaus Maintains Computer Sciences at Buy, Raises PT from $34 to $39': '[[Price Targets]]',
#  "Benzinga's Top Upgrades, Downgrades For March 20, 2019": '[[OTHER]]',
#  'After Chilly Winter, Homebuilders To Share Earnings With High Hopes Ahead': '[[OTHER]]',
#  'Leerink Swann Initiates Coverage on Enanta Pharma at Outperform': '[[Analyst Rating]]',
#  'Titan Machinery Q4 EPS -$0.20 vs -$0.19 est, Revenue $490.7M vs $545.5M est': '[[Earnings]]',
#  'Canadian Banks Still Pay Juicy Dividends (AXP, JPM, TD, RY)': '[[Dividends]]',
#  'Jim Chanos Talks Latest Major Short Win And How To Find New Opportunities': '[[OTHER]]',
#  '6 Things Investors Should Know About The December Market Setup': '[[OTHER]]',
#  'Eaton Vance Corp Plans To Jump Into The ETF Arena With Active ETFs': '[[Products-Services]]',
#  'Orbital Successfully Launches Minotaur I Rocket Supporting ORS-3 Mission for US Air Force ': '[[Products-Services]]',
#  'Barrick Sees FY17 Cooper Production Of 400M-450M Lbs.': '[[Guidance]]',
#  'Laboratory Corp Raises FY Guidance From $8.60 - $8.95 to $8.70 - $8.90 vs $8.81 est': '[[Guidance]]',
#  'Juniper Networks To Discuss Growth Initiatives During Its Analyst Day': '[[OTHER]]',
#  'Tonix Pharma shares are trading lower after the company filed for a $34M stock and warrant offering.': '[[Stock price movement]]',
#  'Mid-Afternoon Market Update: Dow Up Over 200 Points; Lakeland Industries Shares Spike Higher': '[[Stock price movement]]',
#  'Icahn Hertz Global Options Position Said To Expire On June 17, 2016 ': '[[OTHER]]',
#  'Top 4 Small-Cap Stocks In The Staffing & Outsourcing Services Industry With The Highest Dividend Yield': '[[Dividends]]',
# ...
#  'Canaccord Genuity Downgrades Mallinckrodt plc Ordinary Shares to Hold': '[[Analyst Rating]]',
#  'Capital One Financial Initiates Coverage on Boston Properties, Inc. at Equal-weight': '[[Analyst Rating]]',
#  'Avondale Partners Negative On Rails, Reiterates Market Underperform, Sees Energy/Commodity Price Weakness Continuing': '[[Analyst Rating]]',
#  'Cornerstone OnDemand Higher as Barclays Upgraded to Overweight': '[[Analyst Rating]]',
#  'Analyst: Shire Shares Should Rebound, But Sustained Rally Unlikely': '[[Analyst Rating]]',
#  'CLSA Upgrades CF Industries Holdings to Outperform': '[[Analyst Rating]]',
#  'UPDATE: Societe Generale Downgrades Cameron International Corporation as Timing of Material Margin Recovery is Now Uncertain': '[[Analyst Rating]]',
#  'Needham Downgrades iRobot Corporation - Common Stock to Hold': '[[Analyst Rating]]',
#  'OIIM Trading At a "Significant Discount," Sterne Agee Reports': '[[Analyst Rating]]',
#  "UPDATE: Goldman Sachs Adds Ingersoll-Rand To Americas Conviction List, Maintains Buy As Firm Notes 'our conviction in the call has only strengthened in light of a strong order book exiting 2018, improving price/cost, and a conservative guidance range'": '[[Analyst Rating]]',
#  'Bank of America Upgrades NuStar GP Holdings To  Buy': '[[Analyst Rating]]',
#  'Morgan Stanley Upgrades National Retail to Overweight': '[[Analyst Rating]]',
#  'UPDATE: JP Morgan Initiates Coverage on Sigma Aldrich ': '[[Analyst Rating]]',
#  'Career Education Corporation Sees Lower Revenues in 2011': '[[Guidance]]',
#  'Williams Partners Reaffirms Distribution-Growth Guidance Despite Lower Commodity Margins and Earnings Guidance  ': '[[Guidance]]',
#  'UPDATE: Campbell Sees FY17 Adj. Gross Margin ~38%, Sees Generating ~$1.25B In Cash Flow From Operations': '[[Guidance]]',
#  'Heartland Payment Guides 2012 EPS of Atleast $1.56; 2012 Net Revenue of $540M-545M': '[[Guidance]]',
#  'McKesson Raises FY20 Adj. EPS Guidance From $14.00-$14.60 To $14.60-$14.80 vs $14.37 Est.': '[[Guidance]]',
#  'Revised Earnings Guidance For ITC Holdings Corp. (ITC)': '[[Guidance]]',
#  'Crown Castle Sees Q3 Site Rental Revenues $805M to $810M, EPS $1.18 to $1.19 vs $1.18 est': '[[Guidance]]',
#  'Microchip Technology Incorporated Sees Q2 Sales $546.20M vs $567.90M Est': '[[Guidance]]',
#  'Lannett Raises FY20 Adj. Sales Guidance From $525M-$545M To $530M-$550M': '[[Guidance]]',
#  'UPDATE: Marcato Sees 2-3 Times More Upside In Buffalo Wild Wings Stock Price If It Undergoes These Proposals': '[[Price Targets]]',
#  'Perrigo Raises FY19 Adj. EPS Guidance From $3.75-$4.05 To $3.85-$4.05 vs $3.93 Est.': '[[Guidance]]',
#  'LogMeIn Sees FY15 Adj. EPS $1.51-$1.57 vs $1.40 Est., Sales $265M-$266.5M vs $263.9M Est.': '[[Guidance]]',
#  'Cash America Sees Q2 EPS $0.12-$0.18 vs $0.16 Est.; Raises FY16 EPS, Adj. EBITDA Outlook': '[[Guidance]]',
#  'Crane Reaffirms FY16 Outlook: Sales ~$2.7B vs $2.7B Est., EPS $3.85-$4.15 vs $4 Est.': '[[Guidance]]',
#  "UPDATE: Ryder Cuts FY15 EPS from $6.45-$6.55 to $6.17-$6.29 to $6.49 Est., Cites 'Lower Than Expected Results in Fleet Management Solutions'": '[[Guidance]]',
#  'Heidrick & Struggles Says Sees Non-Cash Impairment Charge $6M-$12M In Q4 To Write Off Carrying Value Of Goodwill, Intangible Assets Related To Leadership Consulting Unit': '[[Guidance]]',
#  'Covenant Transportation Group Announces Expectations Concerning Q4Financial Results ': '[[Guidance]]',
#  'Yahoo! Expecting Q3 Sales Ex-TAC $1B-$1.04B vs $1.07B Est., Adj. EBITDA $200M-$240M': '[[Guidance]]',
#  'Viper Energy Partners Sees Q3 Production Up 9% QoQ': '[[Guidance]]',
#  'Royal Caribbean Sees Q3 EPS ~$3.10 vs. Est. $3.39, FY16 EPS $6.00-$6.10 vs. Est. $6.21': '[[Guidance]]',
#  'TE Connectivity Sees Q3 Adj. EPS $1.35 to $1.37 vs $1.37 Est., Sales $3.65B to $3.70B vs $3.63B Est.': '[[Guidance]]',
#  'Watch Specialty Apparel Names Following American Eagle Preliminary Results, Guidance': '[[Guidance]]',
#  'FelCor Lodging Trust Incorporated Sees FY2013 FFO $0.37-0.38': '[[Guidance]]',
#  'LifeLock Sees Q1 EPS $(0.02)-(0.03) vs $0.03 Est; Sees Sales $105.0M-106.0M': '[[Guidance]]',
#  'UPDATE: Illinois Tool Works Raises FY17 EPS Guidance From $6.20-$6.40 To $6.32-$6.52  vs $6.38 Est.': '[[Guidance]]',
#  'From Western Digital Earnings Conference Call: Sees Q2 Adj. EPS $3.60-$3.70 vs $3.51 Est.': '[[Guidance]]',
#  'Destination Maternity Corporation Expects $1.2M-$1.4M In Net Savings From Corporate Restructuring': '[[Guidance]]',
#  'Franklin Electric Increases FY17 EPS Guidance From $1.77-$1.87 To $1.87-$1.97': '[[Guidance]]',
#  'CME Energy Sees FY20 Adj. EPS $2.63-$2.68 vs $2.68 Est.; Reaffirms FY19 Adj. EPS Guidance Of $2.47-$2.51 vs $2.50 Est.': '[[Guidance]]',
#  'Signet Jewelers Sees FY19 Adj. EPS $3.75-$4.25 vs $6.09 Est.; Sales $5.9-$6.1B vs $6.09B Est.': '[[Guidance]]',
#  'Leggett & Platt Raised FY12 EPS Guidance from $1.35-1.50 to $1.45-1.52, vs $1.39, Sales Guidance Raised from $3.65-3.8B to $3.7-3.75B, vs $3.75B': '[[Guidance]]',
#  'SpartanNash Sees FY19 Adj. EPS $1.20-$1.50, Adj. EBITDA $190M-$205M': '[[Guidance]]',
#  'Craft Brew Alliance, Inc. Sees Q4 EPS $0.04 vs $0.05 Est': '[[Guidance]]',
#  'Sagent Pharma. Sees FY16 Rev. $325-$365M vs. Es.t $347.22M': '[[Guidance]]',
#  'James Hardie Industries Expect Our North America Fiber Cement Segment EBIT Margin To Be Between 25% And 27% For Fiscal Year 2020; Says US Housing Market Conditions Remain Somewhat Uncertain And Some Input Costs Remain Volatile': '[[Guidance]]',
#  'UPDATE: Cepheid Sees Q3 Sales Slightly Below Street Estimate': '[[Guidance]]',
#  "Grubhub's Q3 Results Likely Driven By Delivery, Technology Improvements": '[[Guidance]]',
#  'Gildan Activewear, Inc. Sees Q1 EPS $0.28-0.31 vs $0.21 Est; Sees Sales Over $400.0M vs $386.80M Est': '[[Guidance]]',
#  'Duke Energy Earnings Preview: EPS Expected to Fall from Previous Quarter': '[[Guidance]]',
#  'Green Dot Sees Q1 Sales $295M-$300M vs $293.9M Est.; FY18 Adj. EPS $2.81-$2.88 vs $2.61 Est, Sales $982M-$997M vs $988.8M Est.': '[[Guidance]]',
#  'JetBlue Airways Lowers Midpoint Of RASM Guidance By 2 Points': '[[Guidance]]',
#  'Coca-Cola Says Expects Impact of Structural Items, Including New Provision in Venezuela, to be 1-2 Point Headwind on Net FY Revenues': '[[Guidance]]',
#  'Amphenol Says Does Not Expect To Meet Q1 Sales And Adj. EPS Guidance Given Uncertainty Surrounding China Production': '[[Guidance]]',
#  'Mantech Guides FY EPS $2.85 May Not Compare to $2.99 Est; Guides FY12 Revenue $2.7B vs $2.92B Est': '[[Guidance]]',
#  'SuperCom Postpones Earnings Release In Light Of A Likely Subsequent Event That May Impact Year-End Financial Results': '[[OTHER]]',
#  'Hudson Global Sees Q4 Rev. $95-$105M vs. Est. $116M': '[[Guidance]]',
#  'Extreme Networks Guides Q3 EPS $0.06-0.08 vs $0.08 Est': '[[Guidance]]',
#  'Crocs shares are trading higher after the company raised Q4 sales guidance to $195M-$205M compared to the $197M analyst estimate and reported better than expected Q3 sales.': '[[Guidance]]',
#  'From Yum! Call: Co. Has No Plans to Boost Prices in China': '[[Guidance]]',
#  'UPDATE: Cray Sees FY15 Sales $720M-$725M vs $716.8M Est.; Sees FY16 Sales $825M vs $818M Est.': '[[Guidance]]',
#  'FDA Says Some Limited Data To Suggest Convalescent Plasma & Hyperimmune Globulin May Have Benefit In Coronavirus': '[[Regulatory]]',
#  "UPDATE: Endologix Forbearance Deal Informed Parties Co. 10-Q Filing Would Include Statement There Is Substantial Doubt Regarding Co.'s Ability To Continue As Going Concern": '[[Regulatory]]',
#  "Kudlow Tells Reporters Trump Is 'Not Calling Out The Fed'": '[[Regulatory]]',
#  "Dr. Reddy's Files Annual Report on Form 20-F": '[[Regulatory]]',
#  'UPDATE: Chesapeake Says Governance Reforms Will be Helpful to Investors': '[[Regulatory]]',
#  "Canada's Carney Says Bank of Canada Welcomes ECB Bond Purchase Plan; Expecting Commodity Prices to Remain High; Kept Rates Low Due to Strong Dollar": '[[Regulatory]]',
#  'Antares Pharma Announces Issuance of Patent for VIBEX Device Platform ': '[[Regulatory]]',
#  'White House Economic Adviser Kudlow Says Technology Related Issues Are The Most Important Issues In Talks Towards Trade Deal With China': '[[Regulatory]]',
#  'Donald J. Trump Tweet: The World has taken a big step back from potential Nuclear catastrophe! No more rocket launches, nuclear testing or research! The hostages are back home with their families. Thank you to Chairman Kim, our day together was historic!': '[[OTHER]]',
#  "CCUR Announces Receives an Extension Through Nasdaq to Prove the Company is Not a 'Public Shell,' Announces a 1M Share Buyback Program": '[[Regulatory]]',
#  'Pemex Sues ConocoPhillips, Shell in Stolen Gas Lawsuit; Seeks $300M': '[[Regulatory]]',
#  'Mosaic Seeking Simpler Potash Tax, Royalty System in Saskatchewan, According to Spokesperson -Reuters': '[[Regulatory]]',
#  'UK House Of Commons Speaker John Bercow Says He Will Stop Boris Johnson From Closing Parliament To Secure Brexit': '[[Regulatory]]',
#  'Vringo Announces Intention to Seek EN Banc Review of Decision in I/P Engine Case': '[[Regulatory]]',
#  'Agreement Between Elbit Systems and the Georgian Government  ': '[[Regulatory]]',
#  "Jury Finds Amgen's Patents For Repatha Are Valid; Sanofi, Regeneron Have Lost Validity Trial, Conceded Infringement": '[[Regulatory]]',
#  'Merkel Says There Will be a  Structural Balance in Germany in 2014': '[[Regulatory]]',
#  'Euro Falls Once More as Greek Crisis Remains Unresolved': '[[Regulatory]]',
#  "'Senate blocks Trump-backed plan to end government shutdown and fund his border wall' -CNBC": '[[Regulatory]]',
#  'Raptor Pharmaceutical Announces Issuance of Key European Patent Protecting the Cysteamine Portfolio ': '[[Regulatory]]',
#  'Hi-Crush Partners Announces Settlement of Baker Hughes Lawsuit': '[[Regulatory]]',
#  'FDA Says Proposing To Increase Regulatory Requirements Of Surgical Staplers For Internal Use By Reclassifying Them Into A Higher-Risk Category': '[[Regulatory]]',
#  'G20 Financial Officials Tasked Relevant Working Groups To Deliver On The Roadmap By April 15 Meeting': '[[Regulatory]]',
#  'Pfizer Reports CDC Recommends Updated Guidance For Adminstering 2-3 Dose Series TRUMENBA': '[[Regulatory]]',
#  'Extreme Networks Granted Exemption to Soros on Rights Pact, Says Soros may Acquire Added Shares Up to 9.9%': '[[Regulatory]]',
#  'SNB would only scrap the 1.20 CHF cap if inflation was much higher via ForexLive': '[[Regulatory]]',
#  'Tessera Technologies Announces California State Court Confirmed Arbitration Award, Entered Judgment of ~$128.33M Plus Post-Judgment Interest Against Amkor': '[[Regulatory]]',
#  'Bunge Spokesperson Says FDA Notified Co Of Contaminated Canola Meal, Product Did Enter US, Co Faces No Shipping Restrictions': '[[Regulatory]]',
#  "Europe's Auto Safety Panel Says Tesla's Model 3 Set A New Benchmark In Safety": '[[Regulatory]]',
#  'Bloomberg Reporting J&J Looking to Avoid Punitive Damages After Losing Mesh Trial Verdict': '[[Regulatory]]',
#  'POZEN Announces Receipt Of Three Patents From The United States Patent And Trademark Office': '[[Regulatory]]',
#  'Brazil Central Bank Says Credit Growth Likely to Persist; Commodity Prices Lower Since April': '[[Regulatory]]',
#  'Sinocoking Coal and Coke Chemical Industries Obtains New Business Licenses For Three Coal Mine Companies in Baofeng County ': '[[Regulatory]]',
#  'TDAmeritrade Reports Will Transfer Shares to NASDAQ': '[[Stock price movement]]',
#  "CNBC Publishes 'Commerce Secretary Wilbur Ross offers Trump a wide range of options, including higher tariffs, to fight steel, aluminum dumping'": '[[Regulatory]]',
#  "UK's Corbyn Says Tomorrow, EU Will Decide On A Brexit Extension": '[[Regulatory]]',
#  'ITT Educational Services Shares +15% After-Hours as Company Says Submitted 2014 Financial Statements to DoE': '[[Regulatory]]',
#  'Bloomberg Reporting VirnetX Jury Cannot Reach Unanimous Verdict in Cisco Case': '[[Regulatory]]',
#  'PG&E Files Formal Papers on Chapter 11 Restructuring Strategy; Plan Offers Nearly $18B to Wildfire Victims and Public Entities': '[[Regulatory]]',
#  "Mylan Invalidates Two of Teva's Copaxone 40 mg/mL Patents Via U.S. Patent and Trademark Office's Inter Partes Review Proceeding": '[[Regulatory]]',
#  "UPDATE: 22nd Century Says 'has not received any notice of, and the Company has no knowledge of, any enforcement proceeding against 22nd Century by the SEC or any other regulator'": '[[Regulatory]]',
#  'Watching Shares of New York Times Amid Reports Pres. Trump Is Looking At Possible Legal Action Against The Paper In Relation To The Recent Anonymous Op-Ed It Published About His Administration': '[[Regulatory]]',
#  'Ultratech Achieves ISO 9001 and 14001 Certification for Singapore Operations and Recertification for U.S. Facility ': '[[Regulatory]]',
#  'Stein Mart Announces It Qualifies For Recently Announced Temporary Relief From Compliance With The Nasdaq Stock Market': '[[Regulatory]]',
#  "Mylan Reports Teva Dismissed Litigation After Co. Won Court Ruling On Teva's Cold Filtration Patents For Copaxone 40 mg/mL": '[[Regulatory]]',
#  "STAT News' Adam Feuerstein Tweets: $TXMD Regulatory update on resolving the TX-004 complete response letter does not read well at all.": '[[Regulatory]]',
#  "Wall Street's M&A Chatter From May 9: Abercrombie & Fitch, GrubHub, Hertz, Lululemon, Broadcom-Brocade, Apollo-West Corp": '[[Mergers and Acquisitions]]',
#  'Eros International Acquires Music Messaging Innovator PingTune, no terms': '[[Mergers and Acquisitions]]',
#  'BMO Financial To Buy KGS-Alpha Capital Markets, No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  'SAP Said to End Talks to Purchase Jive Software -Bloomberg': '[[Mergers and Acquisitions]]',
#  'Community Health Systems Announces Definitive Agreement To Sell Bluefield, West Virginia Hospital': '[[Mergers and Acquisitions]]',
#  'Eaton Agrees to Acquire Medium Voltage Switchgear Manufacturer E.A. Pedersen Company': '[[Mergers and Acquisitions]]',
#  'Verisk Analytics Reports Purchase of Analyze Re, No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  "Constant Contact Announces Deal to Be Purchased by Endurance Int'l at $32/Share": '[[Mergers and Acquisitions]]',
#  'Bristol-Myers, AstraZeneca Shares Higher Following Confirmation AstraZeneca Will Buy JV Diabetes Stake for Up to $4.3B': '[[Mergers and Acquisitions]]',
#  'Archer Daniels Midland Reports Will Buy Remaining 20% Minority Stake of Alfred C. Toepfer for €83M': '[[Mergers and Acquisitions]]',
#  'KKR Invests in Shenzhen Suishou Technology; Financial Details Not Disclosed': '[[Mergers and Acquisitions]]',
#  'Navios Maritime Acquisition Corporation And Navios Maritime Midstream Partners L.P. Announce Definitive Merger Agreement': '[[Mergers and Acquisitions]]',
#  'Publicis Groupe Extends Offer to Purchase all Sapient Shares for $25.00/Share to January 22, 2015': '[[Mergers and Acquisitions]]',
#  'Rovi to Acquire Veveo for $62M in Cash at Closing, Plus $7M in Additional Cash Payments Based on Milestones': '[[Mergers and Acquisitions]]',
#  "MetLife Announces Acquisition of BBVA's Chilean Pension Business for Approximately $2B": '[[Mergers and Acquisitions]]',
#  'RTI Surgical Reports Purchase Of Zyga Technology, No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  'GSE Systems Reports Purchase Of Absolute Consulting For $8.75M In Cash': '[[Mergers and Acquisitions]]',
#  'REMINDER: Rent-A-Center Shareholders Vote Today On M&A With Vintage Capital; BZ NOTE: On September 13 The Co. Reported a 2nd HSR Request For Info From The FTC Regarding The Deal': '[[Mergers and Acquisitions]]',
#  "'China Hasn't Started Remedy Talks On Mellanox/NVIDIA' - Deal Reporter": '[[Regulatory]]',
#  'Wabtec Reports Deal to Buy Faiveley Transport for $1.8B': '[[Mergers and Acquisitions]]',
#  'Carriage Services Reports Purchase Of Assets Of Oakmont Memorial Park & Mortuary, No Terms Disclosed': '[[Mergers and Acquisitions]]',
#  "Paragon Offshore's Norwegian Buy Doesn't Move Market": '[[Stock price movement]]',
#  'Rice Energy Release Confirms Closing of Rice Midstream Partners LP: 28.75M Common Units at $16.50/Unit': '[[Mergers and Acquisitions]]',
#  ...}

# %%
import re
from collections import Counter
import random


def clean_llm_prediction(pred):
    # try:
    matches = re.search(r'\[\[[^\]]+\]\]', pred)
    try:
        pred = matches[0]
        pred = pred.replace(']]', '')
    except:
        pred = "other"
    pred = pred.lower() 
    for k in event_types_mapping:
        if k.lower() in pred:
            pred = k.lower()
            return pred
    return pred


correct = 0
total = 0
y_pred = []
y_true = []
majority_counts = 0

relevant_classes = {
                   # "management changes",
                   # "labour issues",
                   # "regulatory",
                   # "stock price movement",
                   # "products-services",
                    "other"
                  }


for text in test_labels:
    pred = clean_llm_prediction(predictions[text])
    clean_label = test_labels[text].lower()
    if pred != clean_label:
        print(text)
        print(predictions[text])
        print(pred)
        print(test_labels[text].lower())
        print()
        print('-----')
    else:
        correct += 1
    total += 1

    y_true.append(event_types_mapping.get(test_labels[text].lower(), 13))
    y_pred.append(event_types_mapping.get(pred, 13))

# print(correct /total), majority_counts, total
# Out:
# Allied Nevada Appoints Director, Corporate Environmental Affairs
# [[Regulatory]]
# regulatory
# management changes
#
# -----
# InnerWorkings Postpones Annual Shareholder Meeting As Co. In In The Process OF Restating Its Financial Statements
# [[OTHER]]
# other
# regulatory
#
# -----
# Deutsche Bank May Have Hired BofA's Jeff Rose - WSJ
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Jefferies Says The 'Transition Continues' At Rackspace
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Mad Money Lightning Round: Cramer Likes Buffalo Wild Wings, Alcoa (BWLD, IDCC, IBKR, AA, PNRA, CMG, HCBK, FNFG)
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Lumos Networks Announces CFO Harold Covert Resigning for 'Family Reasons,' Johan Broekhuysen Named as Interim CFO
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Buffett: Corporate Taxes Not 'Strangling' US Competitiveness -CNBC
# [[Regulatory]]
# regulatory
# other
#
# -----
# UPDATE: Mizuho On United Health Also Notes Co's 'Revenue Diversification at Optum a Key Differentiator'
# [[Analyst Rating]]
# analyst rating
# products-services
#
# -----
# Hearing Mosaic Has Laid Off ~368 Workers, 95% of Headcount at Colonsay, Saskatchewan Potash Mine
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Shares of several software companies are trading higher after Trump administration eased the ban on Huawei after technology stocks tumbled.
# [[Stock price movement]]
# stock price movement
# regulatory
#
# -----
# China LED Chip Makers See High Inventory Due to Oversupply
# [[OTHER]]
# other
# products-services
#
# -----
# Millennial Media Appoints Ross Levinsohn and Tom Evans to Its Board of Directors
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# CenterPoint Energy Announces Carla Kneipp VP and Treasurer
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# US Stock Futures Tumble; Citigroup Earnings In Focus
# [[OTHER]]
# other
# stock price movement
#
# -----
# Chinese FX Reserves Climb Past $3 Trillion, Inflation Concerns Mount (CNY)
# [[Regulatory]]
# regulatory
# other
#
# -----
# Airlines, Governments And 3PLs Get Creative With Emergency Airlifts
# [[OTHER]]
# other
# products-services
#
# -----
# Monster Beverage Board Declares Three-for-One Stock Split
# [[OTHER]]
# other
# stock price movement
#
# -----
# Smith Micro Announces Tim Huffmyer CFO, Previous CFO Resigned to Pursue Other Interests
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# DJ Redbook: Reports U.S. Retail Salres First 5 Weeks Down 0.4% MoM, Up 0.6% YoY; Up 1.3% Week End Oct 1 YoY
# [[Stock price movement]]
# stock price movement
# earnings
#
# -----
# Green Dot Has 24% Upside As It Pivots From Prepaid Market To Full-Fledged Fintech
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# REMINDER: ASH Meeting Begins Tomorrow Dec. 9, Presenters Include Bellicum Pharmaceuticals, Affimed, Cellectis (Pediatric Data for UCART19), and Acceleron Pharma
# [[OTHER]]
# other
# products-services
#
# -----
# Putin Says United States Is Not Taking Russian Share On Global Energy Market
# [[Regulatory]]
# regulatory
# other
#
# -----
# July Video Game Sales Down 8% Y/Y (ATVI, ERTS, THQI, TTWO)
# [[Stock price movement]]
# stock price movement
# earnings
#
# -----
# Option Alert: ZIOP Mar16 12.0 Calls: 700 @  ASK  $0.05: 700 traded vs 840 OI:  Earnings today  $8.00 Ref
# [[Earnings]]
# earnings
# stock price movement
#
# -----
# Black Rock Affirms it Will Not Acquire More than 4.9% of Common Stock of Level 3
# [[Regulatory]]
# regulatory
# mergers and acquisitions
#
# -----
# 8 Technology Stocks Moving In Friday's Pre-Market Session
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Form 8-K from Wesco Shows Co. Boosted Purchase Limit Under Receivables Facility from $475M to $500M, Can Increase Limit Added $100M
# [[Regulatory]]
# regulatory
# earnings
#
# -----
# WHO Head Tedros Highlights Number Of Cases In China Continues To Decline
# [[OTHER]]
# other
# regulatory
#
# -----
# 8-K from Key Tech Shows Co. Incurred Restructuring Charges Related to Personnel Expenses, Sees Pre-Tax Charges ~$580K
# [[Labour Issues]]
# [[labour issues
# earnings
#
# -----
# 15 Industrial Stocks Moving In Monday's Pre-Market Session
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# ANF Shareholder Engaged Capital Retains Advisors to Aid in Efforts to Set New Direction for Co
# [[OTHER]]
# other
# management changes
#
# -----
# Can Lennar Post Low-Teens EPS Growth? Experts & Crowd Disagree
# [[Guidance]]
# guidance
# other
#
# -----
# Sterne Agee On Whole Foods: 'When You Don't Know The Bottom, It's Hard To Step In And Buy The Stock'
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Hearing Gabelli Saying Appointment Of Mr. McCollum Increases Likelihood Halliburton Will Acquire WFT Down The Road
# [[OTHER]]
# other
# mergers and acquisitions
#
# -----
# Jim Cramer Says Joy Global's Buyout Is A 'Remarkable Deal'
# [[OTHER]]
# other
# mergers and acquisitions
#
# -----
# Dreamworks Animation SKG (DWA) Climbs After Upgrade To Overweight
# [[Analyst Rating]]
# analyst rating
# stock price movement
#
# -----
# Apple and Boeing Earnings, Plus Oil Drag, Combine To Dent Stocks
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Innate Pharma Announces  AstraZeneca to Advance Monalizumab to Phase III in Head and Neck Cancer
# [[Products-Services]]
# products-services
# product approval
#
# -----
# PacCrest Analyst Sees Early Checks In Adobe 'Encouraging'
# [[Analyst Rating]]
# analyst rating
# guidance
#
# -----
# Top Performing Industries For December 2 (WBD, CRH, LOW, SMS)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Top 10 Most Overbought Stocks Via Benzinga Pro's Radar Tool For Wed., June 19, 2019
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Mad Money Lightning Round: Cramer Advises Investors To Buy Peabody Energy (COP, ARG, MOS, POT, DTG, MLNX, RVBD, ONNN, DE, BTU)
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Towerstream Reports Record Number of Contracts from Nov
# [[Products-Services]]
# products-services
# guidance
#
# -----
# BlackBerry's Good Technology Acquisition Is 'Positive' For Company, JP Morgan Says
# [[Analyst Rating]]
# analyst rating
# mergers and acquisitions
#
# -----
# USA EIA Natural Gas Inventories for Apr 24 Build 70 bcf vs Build 69 bcf Est; Prior Build 43 bcf
# [[OTHER]]
# other
# earnings
#
# -----
# Metals Higher This Morning, Led By Copper (SLV, GLD, JJC, PALL, PLTM)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# 8-K from EA Shows Chairman Lawrence Probst III to Step Down, Will Continue as Non-Exec Chair
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# WBI Shares' New Fund Chases Bulls Via Tactical Reallocation, Investing In Other ETFs
# [[Products-Services]]
# products-services
# other
#
# -----
# Nustar GP Holdings Chairman Greehey Buys 70,097 Shares @$33.57/Share -Form 4
# [[OTHER]]
# other
# stock price movement
#
# -----
# Before Syria Blowup, Short Interest In Defense Stocks Shrank (GD, HII, UTX)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# UPDATE: ChemoCentryx, Vifor Entered Amendment To Collaboration, License Deal To Account For Exclusive License To Commericialize CCX140 In Certain Countries Outside US, Vifor To Pay ~$11.5M
# [[Products-Services]]
# products-services
# mergers and acquisitions
#
# -----
# Jiayuan.com Special Committee Engages Financial Advisor and Legal Counsel to Assist in Review of 'Going Private' Offer
# [[Mergers and Acquisitions]]
# mergers and acquisitions
# regulatory
#
# -----
# Mitel Views Mavenir Purchase Modestly Dilutive In Second Half Of 2015
# [[Guidance]]
# guidance
# mergers and acquisitions
#
# -----
# BlackBerry And CEO John Chen Agree to Contract Extension Through Nov. 2023
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Westar Energy, Wisconsin Energy, Exelon Shares Tumble to Session Lows Following Mid-Day Downgrades from Edward Jones
# [[Analyst Rating]]
# analyst rating
# stock price movement
#
# -----
# Shares of Kite Pharma Rise as Much as 54% After-Hours Monday on Positive Non-Hodgkin's Lymphoma Trial Results Using KTE-C19
# [[Products-Services]]
# products-services
# stock price movement
#
# -----
# Wendy's Arby's Group Ticking Higher On Renewed Takeover Chatter (WEN)
# [[Stock price movement]]
# stock price movement
# mergers and acquisitions
#
# -----
# Option Alert: Sproutts FM Jul 20.0 Calls: 1000 @  ASK  $1.10: 1173 traded vs 5 OI:  Earnings 8/3 Before Open (est)  $19.91 Ref
# [[OTHER]]
# other
# stock price movement
#
# -----
# UPDATE: Height Securities Raises Odds Individual Healthcare Mandate Repeal Remains In Final Tax Bill To 75%, Calls This Tailwind For Short-Term Medical Insureres (e.g. JP, IHC, HIIQ, EHTH), Minor Headwind For Managed Care And Hospitals (e.g. CNC, MOH)
# [[Analyst Rating]]
# analyst rating
# regulatory
#
# -----
# Assured Guaranty (AGO) Shares Rise As Q4 Results Defy Analysts’ Expectations
# [[Earnings]]
# earnings
# stock price movement
#
# -----
# American Homes 4 Rent Earlier Reported Bryan Smith As COO
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Omnicom Announces Randall Weisenburger Steps Down As CFO
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# LEDinside Says Decreasing LED Bulb Price Trend to Continue in 2014 -Digitimes
# [[OTHER]]
# other
# products-services
#
# -----
# Hawaiian Airlines Reports November Load Factor Decreased 1.8 Points To 84.1%
# [[OTHER]]
# other
# earnings
#
# -----
# The Biotech Stock With The Best One-Week Performance
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Jobless Claims Up, But Trend Still Down - Analyst Blog
# [[OTHER]]
# other
# labour issues
#
# -----
# Editor of Little Bear Blog Says Time to Begin Covering Oracle Short Here
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Lavazza Reports 6.8% Stake in Green Mountain Coffee
# [[Mergers and Acquisitions]]
# mergers and acquisitions
# other
#
# -----
# Retail Economist/Goldman Sachs Chain Store Sales Down 0.8% In Nov 10 Week, Up 1.8% Year Over Year
# [[Stock price movement]]
# stock price movement
# earnings
#
# -----
# Black Box Shares Now Trading Up 100% For The Session After Co. Earlier Announced Data Center Contract With Social Media Company
# [[Products-Services]]
# products-services
# stock price movement
#
# -----
# 13F From Omega Shows Increased Stake In Sinclair Broadcast Group; Exited Stake In Tribune Media, Walgreens Boots Alliance and Weatherford International
# [[OTHER]]
# other
# mergers and acquisitions
#
# -----
# After Chilly Winter, Homebuilders To Share Earnings With High Hopes Ahead
# [[OTHER]]
# other
# guidance
#
# -----
# Juniper Networks To Discuss Growth Initiatives During Its Analyst Day
# [[OTHER]]
# other
# guidance
#
# -----
# Icahn Hertz Global Options Position Said To Expire On June 17, 2016
# [[OTHER]]
# other
# stock price movement
#
# -----
# Southern Union Company Up Nearly 15% in Pre-Market on Buyout Offer
# [[Mergers and Acquisitions]]
# mergers and acquisitions
# stock price movement
#
# -----
# iGATE Proposes to Launch Process to Delist Patni Computer Systems Limited
# [[Mergers and Acquisitions]]
# mergers and acquisitions
# regulatory
#
# -----
# JMP Securities Sees Reasons For Long-Term Optimism For Progress Software
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Daily Telegraph's Christopher Hope Reports Boris Johnson To Address Mass Meeting Of 1922 Committee Of Conservative Backbenchers
# [[OTHER]]
# other
# regulatory
#
# -----
# UPDATE: UBS On Monster Notes 'our normalized estimate for US growth of +3.6% adj. for advance shipment compare ($16M) and extra shipping day (+1.5%) suggests negative underlying volume growth inclusive of the Reign rollout contribution'
# [[Analyst Rating]]
# analyst rating
# guidance
#
# -----
# Redbook Reports US Retail Sales During First 3 Weeks Of Feb. Down 1.4% Month Over Month, Up 5.1% Year Over Year
# [[Stock price movement]]
# stock price movement
# earnings
#
# -----
# Giga-tronics Reports $3.4M Private Placement Financing
# [[OTHER]]
# other
# stock price movement
#
# -----
# Casablanca Issues Comment on Cliffs Natural Resources' 'Desperate Ploy to Maintain Status Quo'
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# Level 3 Earlier Said Recommends Holders Reject Offer By TRC Capital At $50.50/Share
# [[Regulatory]]
# regulatory
# analyst rating
#
# -----
# NXT-ID Reports Issuance Of Patent For IoT Device Collaboration
# [[Regulatory]]
# regulatory
# products-services
#
# -----
# BNY Mellon Appoints James Wiener As Chief Risk Officer
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Radius Health 10%+ Owner BB BIOTECH AG (10%+) Buys 50,000 @ Avg Price: $26.25 Form4
# [[OTHER]]
# other
# stock price movement
#
# -----
# Kopin Chairman Fan Buys 116,400 Shares @$2.83/Share -Form 4
# [[OTHER]]
# other
# stock price movement
#
# -----
# Shares of several semiconductor companies are trading higher after Broadcom reported better-than-expected Q1 EPS and issued strong FY19 guidance.
# [[Stock price movement]]
# stock price movement
# earnings
#
# -----
# Ares Commercial Real Estate Names Former CEO of CBRE to Board
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# IES Holdings Announces Appointment Of Gary Matthews As CEO
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Shares of CommVault Spike Following Piper Jaffray's Comments
# [[Analyst Rating]]
# analyst rating
# stock price movement
#
# -----
# Nelson Peltz And Pentair: Could M&A Be On The Horizon?
# [[OTHER]]
# other
# mergers and acquisitions
#
# -----
# A Peek Into The Markets: US Stock Futures Down, Morgan Stanley Earnings Miss In Focus
# [[Earnings]]
# earnings
# stock price movement
#
# -----
# Deckers Outdoor Falling On Heavy Volume Again (DECK)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# D.A. Davidson on Anadigics: Awaiting Long-Term Catalyst
# [[Analyst Rating]]
# analyst rating
# other
#
# -----
# La Jolla Pharmaceutical Company Reports Exclusive Worldwide License Agreements Covering LJPC-30Sa and LJPC-30Sb
# [[Products-Services]]
# products-services
# regulatory
#
# -----
# Technicals Show The Silver ETF (SLV) May Have Bottomed
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Starwood Shares Largely Unch as Co. Announces Multi-Billion Dollar Investment in Le Meridien Global Portfolio
# [[Products-Services]]
# products-services
# mergers and acquisitions
#
# -----
# Short Interest in AngloGold Ashanti, IAMGOLD Continues to Surge (AU, IAG, KGC)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# UPDATE: Moody's Says Debt Ceiling Boost Eliminates Risk of Default
# [[Regulatory]]
# regulatory
# credit ratings
#
# -----
# S&W Secures New $35M Working Capital Facility With CIBC
# [[Regulatory]]
# regulatory
# credit ratings
#
# -----
# S&P Assigns Negative Outlooks On U.S.-Based Insurance Groups
# [[Regulatory]]
# regulatory
# credit ratings
#
# -----
# Rackspace To Enter Public-Partnership With Austin Community College; Will Move 570 Of Rackspace's Austin Employees To Acc's Highland Campus
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# CSX, Mechanical Unions Report Progressive Labor Partnership
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Broadcom 10-Q Discloses ~1100 Employees Terminated As Result Of Brocade Merger
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: EQT To Cut Workforce By ~23%, Or 196 Positions; Will Represent ~$50M Of Annual General & Administrative Costs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: Lattice Semi Says ~150 Employees In Co.'s HDMI, Related Products Of Lattice In US, China, India Will Be Offered Employment At INVECAS
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Ulta Announces To Temporarily Furlough Store And Salon Associates
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Delta Airlines Will Pay Out $1.1B In Profit-Sharing With Employees
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Tesla To Reduce 75% Of All On-Site Staff At Nevada Gigafactory Due To Pandemic
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# This Day In Market History: 3,400 UAW Workers Walk Out Of GM Plant
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Seagate Technology To Cut Workforce By 1,050 in 8K Filing
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# JC Penney Temporarily Lays Off Majority Of Store Hourly Associates, Effective Apr. 2
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# SpartanNash Outlines Hiring Initiative Related To Displaced Workers, Students At Retail Locations
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# GM-UAW Strike Nears Third Week, Costing Thousands Their Jobs And The Company Millions
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# New York Times Says It Will Cut 50 Non-Newsroom Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Spruce Point Capital Tweets: Spruce Pt tgt $SABR cutting 9% of workforce, trimmed top end of Ad EBITDA, never forget the warning about inability to provide GAAP figures
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Automakers, Tire Manufacturers Announce Plant Closures In Mexico
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# 'Facebook Employees Stage Virtual Walkout to Protest Trump Posts' -Breaking New York Times Report
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Meredith Whitney Says Banking Sector Will Lose 50,000 More Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# In A Presentation, Deutsche Bank Says It Targets Reducing Group Headcount To Below 93K By End-2018
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Ford To Cut 7K Salaried Jobs Worldwide As Part Of Restructuring
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Hearing Petrobras Board Names Ivan Monteiro Interim CEO Following Parente Resignation
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Popeyes Louisiana Kitchen Names John Merkin COO-U.S.
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# 'Walmart poaches ex-Google, Amazon exec Suresh Kumar for new CTO role' -CNBC
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Sohu.com Says Wang Resigned as COO for Personal Reasons
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Univest Financial Corporation Announces Retirement Of Chief Financial Officer And Planned Succession
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Orexigen Therapeutics Announces Promotions of Tom Cannell to COO and Jason Keyes to CFO
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Francesca's Reports Chief Merchandising Officer Sei Jin Alt To Retire
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Regions Announces Fournier J. Gale Moved To Senior Advisory Role;m Tara A. Plimpton Named General Counsel
# [[Labour Issues]]
# [[labour issues
# management changes
#
# -----
# Mylan Confirms In PR Minivelle First-to-File Patent Challenge
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# Seagate's Self-Encrypting Laptop Hard Drive First to Win Key U.S. Government Certification
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# South Korea Grants Lightbridge Key Patent for Metallic Nuclear Fuel Design
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# Horizon Pharma Announces U.S. Patent Office Issuance Of Notice Of Allowance With Claims Covering RAVICTI
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# Analysts: Athletic Brands Aren't Making Enough Products For Women
# [[Products-Services]]
# products-services
# other
#
# -----
# Top Performing Industries For April 20 (IPG, HOG, MGM, HMA, BHI)
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# January Class 8 Orders Remain Low But Outperform Year Ago
# [[Stock price movement]]
# stock price movement
# other
#
# -----
# Earth To Elon: Musk Wants To Conquer Music And The Ways It's Delivered
# [[Products-Services]]
# products-services
# other
#
# -----
# Philippines ETF Hits New High as S&P Joins Investment-Grade Party
# [[Stock price movement]]
# stock price movement
# credit ratings
#
# -----
# Moody's Changes Outlook on Greece's Banking System to Stable from Negative
# [[Regulatory]]
# regulatory
# credit ratings
#
# -----
# Fitch Revises India's Outlook to Negative; Affirms at 'BBB-'
# [[Regulatory]]
# regulatory
# credit ratings
#
# -----
# Allergan Announces Will Restructure, Expecting to Cut Headcount by 1,500 Positions
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Sears Says Holiday Hiring On Pace for About Same as Last Year; Will Introduce Mobile Checkouts in Stores -Bloomberg
# [[Products-Services]]
# products-services
# labour issues
#
# -----
# Lowe's Lays Off Thousands Of Store Workers; Lowe's To Outsource Maintenance, Assembly Work To Third Party Vendor
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# JC Penny Shares Fall 6% Premarket to $8.38 Following NY Post Report on Co Taking Emergency Measures Including Cutting Payroll
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Google Confirms That Is Temporarily Shutting Down All China Offices Due To Coronavirus Outbreak
# [[Regulatory]]
# regulatory
# labour issues
#
# -----
# Sunpower Says On Feb. 21st, It Began Implementing Initiatives To Reduce Op. Expenses, Expects To Between 150-250 Jobs, Representing An Impact To 3% Of Co.'s Global Workforce
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Form 8-K from JetBlue Shows Arbitrator Denied Claims from 2009 in Base Pay Dispute, Said 2007 Pay Adjustments Triggered Provision
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Bloomberg Reporting Airbus Going through "Complex" Talks with Works Councils; Restructuring Implementation to Begin in 2H
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Wells Fargo To Eliminate 2016 Bonuses For Top Execs, Discussed Withholding Bonuses From CEO Sloan and CFO Shrewsberry According To Dow Jones Sources
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# From Navistar Earnings Release: Co. to Reduce Headcount by ~500 Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Fired American Realty Capital Accounting Officer Sues Company, Claims Defamation, Alleges Accounting Manipulation
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Hearing Time Internal Memo Shows Co. Will Reduce Workforce By 300 Jobs (4% Of Workforce) Via Layoffs, Buyouts
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# JPMorgan Set To Cut 1% Of All Jobs In Consumer Unit: Report
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# South Africa's Mining Industry, Unions, Government Agree to Plan to Stem Job Losses, Delays Layoff, Sell Distressed Assets, Promote Platinum as Central Bank Reserve Asset -Reuters
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Home Depot Canada Announces Will Hire Nearly 6K Associates for Springtime Seasonal Hiring
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Unilife 8-K Shows Co. Plans To Cut 17% Of Workforce (50 employees) And Plans To Cut OpEx In 2016
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Chipotle Shares Unaffected Amid Headline City Of New York Has Sued Co. For Violating Fair Workweek Law
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Universal Electronics Outlines 4 Steps In Corporate Restructuring
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Urban Outfitters to Close All Stores Worldwide Due to Coronavirus Until at Least March 28
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# American Express Has Suspended A Staff Director Related To A Forex Pricing Probe
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Simon Property Group Shares Quiet Following Report Co. Laying Off 30% Of Its Workforce
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Arcos Dorados Shares Tick Lower As Hearing Peruvian Labor Watchdog Says Co. Guilty Of Serious Labor Violations Related To Employee Deaths At McDonald's
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Mid-Day Market Update: Wednesday's Movers, China Intervenes With Yuan And Kraft Heinz Job Cut
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Public Service Electric And Gas To Temporarily Close Customer Service Centers, Suspend Shut Offs For Non Payment
# [[Regulatory]]
# regulatory
# labour issues
#
# -----
# Chesapeake Energy CEO Says In A Letter To Employees They Reduced Workforce By 13% This Morning
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Verso Corp 8-K Filing Shows Co. Will Reduce Production Capacity At Paper/Pulp Mills In Maine Indefinitely
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Hearing HollyFrontier Has Said Reduced Production Rates at El Dorado, KS Plant from 138K Barrels/Day to ~98K Following Discovery of Hole in Sulfur Recovery Unit
# [[Products-Services]]
# products-services
# labour issues
#
# -----
# Universal Electronics Announces Corporate Restructuring
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Navistar Takes $140 Million Revenue Hit From UAW-GM Strike
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: eBay Says Took Q4 Restructuring Charge of $31M Related to Headcount Reduction
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Will The Pilot’s Strike Push Spirit Into Bankruptcy?
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# 8-K from Interphase Shows Co. Expecting to Reduce Headcount by 15-25%; Expecting $50K-$150K Termination Benefits Charge
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: Eli Lilly Says Streamlining Of Operations Will Impact ~8% Of Workforce, Or About 3,500 Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Macy's, Inc. to Hire 78,000 Seasonal Associates in 2011
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Delta To Buy Out Employees, Offer Early Retirement (DAL)
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Teamsters Local 120 Issues Press Release Highlighting 'Another' Confirmed Case Of Coronavirus At United Natural Foods' Hopkins, Minnesota Warehouse, Calls On State Health Officials To Step In Before State's Grocery Supply Is Affected
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Tuesday Morning Corporation's Statement Regarding Alleged Termination Claim
# [[OTHER]]
# other
# labour issues
#
# -----
# Mid-Morning Market Update: Markets Open Lower; JC Penney To Close Up To 140 Stores
# [[Stock price movement]]
# stock price movement
# labour issues
#
# -----
# Bloomberg Reporting Bank of Ireland, Labor Union Said to Be Near Pension Deal
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Polycom 8-K: Company To Cut Global Workforce By 11%
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Penn West Petroleum Says Will Cut 35% of Workforce to Cut Costs, Defering $75M of 2015 Capital Spending, Cutting Board Retainer
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Sodastream Says Histadrut Union Notified Company That Sodastream's Israeli Subsidiary Employees Decided To Join Labor Union
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Newpark Outlines Implementation Of Cost-Reduction Programs, Including Workforce, Bonus Suspension, Salary Cuts, Elimination Of Non-Essential Capital Investments, Cuts FY20 Capex To $15M-$20M
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# YRCW Gets Concession from Teamsters - Analyst Blog
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Skyline Champion Suspends Operations at Some of its Facilities in Response to Coronavirus
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Qualcomm Said to Hire GM's Ex-Futuristic Vehicle Developers -Bloomberg
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Fastenal In Mid-March 2020, Established Operating Expense Reductions Within Business; Included In Operating Expense Reductions Was Decision To Eliminate Most Leadership Bonuses During Q2 Of 2020
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: NFL Player Representatives Approve Collective Bargaining Agreement
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Lyondell Houston Refinery Gasoline Unit May Be Shut 3 Weeks
# [[OTHER]]
# other
# labour issues
#
# -----
# UAW Executive Board Files Article 30 Charges Against Gary Jones And Vance Pearson
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# SkyWest Will Be Impacted By American's Decision To Cut Ties With ExpressJet
# [[Regulatory]]
# regulatory
# labour issues
#
# -----
# Wayfair To Open New Facility In Savannah, Add 1,000 Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: Crown Holdings Cutting Jobs Across Europe, Sees Reduction Affecting ~300 Employees
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Micron Shares Unaffected As Hearing Co. Has Committed To 90-Day No Layoff Plan
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Does a Minimum Wage Hike Threaten Retailer JC Penney?
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Deutsche Bank Considering To Cut Thousands More Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Agrium Announces Production As Vanscoy Potash Mine Shutdown Following Mechanical Error
# [[Products-Services]]
# products-services
# labour issues
#
# -----
# How to Profit as the United Kingdom is Brought to Standstill by Strikes
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Kinross Gold Says Closed Toronto Office Wed. After Employee Tested Positive For Coronavirus
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: Whirlpool Sees $500M Restructuring Charge, Cutting About 5,000 Jobs
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Ford Spokesperson Says Has Not Lost Any Auto Production Outside US Amid Coronavirus
# [[OTHER]]
# other
# labour issues
#
# -----
# Teamsters Says Allegiant Air Pilots Representd By Airline Professionals Association Teamsters Local 1224 Voted to Authorize Strike -Reuters
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# UPDATE: Tenneco Began Implementing Headcount Reduction On Jan. 30, 2019; Sees Incurring $40M-$45M Charge In Q4'18
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# CME To Shut Down Chicago Trading Floor Over Coronavirus Concerns
# [[Regulatory]]
# regulatory
# labour issues
#
# -----
# Pepsi Shares Unaffected Following Earlier Story from Philly.com 'Pepsi to lay off 80 to 100, blames soda tax'
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# Tyson Foods Says It's Shut Meat Plants In Georgia And Florida In Response To Hurricane Irma
# [[Labour Issues]]
# [[labour issues
# labour issues
#
# -----
# USPTO Grants Codexis Patent for Enzymes Used in Hep-C Therapeutics
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# Sucampo Receives Notice from MHRA in UK that Second Indication for AMITIZA for Opioid-Induced Constipation Is Not Approved
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# The Daily Biotech Pulse: FDA Nod For Pfizer, Vanda Forges Partnership For COVID-19 Drug Research, Neuronetics Pre-Announces Revenue Shortfall
# [[OTHER]]
# other
# product approval
#
# -----
# FMC Receives Regulatory Approval In India For Acquisition Of A Portion Of DuPont's Crop Protection Business
# [[Mergers and Acquisitions]]
# mergers and acquisitions
# product approval
#
# -----
# Ball Aerospace Satellite Passes Pre-Environmental Review (BLL)
# [[Products-Services]]
# products-services
# product approval
#
# -----
# The Daily Biotech Pulse: Sorrento Submits EUA Application For Rapid Coronavirus Test, Decision Day For Viela, Lantern Pharma IPO
# [[Products-Services]]
# products-services
# product approval
#
# -----
# Williams Partners Receives FERC Approval for Transco Pipeline Expansion
# [[Regulatory]]
# regulatory
# product approval
#
# -----
# US Navy Accepts General Dynamics-built MUOS Ground Stations
# [[Products-Services]]
# products-services
# product approval
#
# -----
# Jim Cramer Sees Bull Market In The Pet Food Sector (DLM, CL, PETM, PETS)
# [[OTHER]]
# other
# analyst rating
#
# -----
# UPDATE: Marcato Sees 2-3 Times More Upside In Buffalo Wild Wings Stock Price If It Undergoes These Proposals
# [[Price Targets]]
# price targets
# guidance
#
# -----
# SuperCom Postpones Earnings Release In Light Of A Likely Subsequent Event That May Impact Year-End Financial Results
# [[OTHER]]
# other
# guidance
#
# -----
# Donald J. Trump Tweet: The World has taken a big step back from potential Nuclear catastrophe! No more rocket launches, nuclear testing or research! The hostages are back home with their families. Thank you to Chairman Kim, our day together was historic!
# [[OTHER]]
# other
# regulatory
#
# -----
# TDAmeritrade Reports Will Transfer Shares to NASDAQ
# [[Stock price movement]]
# stock price movement
# regulatory
#
# -----
# 'China Hasn't Started Remedy Talks On Mellanox/NVIDIA' - Deal Reporter
# [[Regulatory]]
# regulatory
# mergers and acquisitions
#
# -----
# Paragon Offshore's Norwegian Buy Doesn't Move Market
# [[Stock price movement]]
# stock price movement
# mergers and acquisitions
#
# -----
# E*TRADE Shares Up ~$0.20 Over Last Min as Hearing Traders Circulating Report of Takeover Chatter
# [[Stock price movement]]
# stock price movement
# mergers and acquisitions
#
# -----
# Charles Gasparino Tweets: Bankers say low odds of $dis $cmcsa bid for $foxa more now @FoxBusiness @TeamCavuto
# [[OTHER]]
# other
# mergers and acquisitions
#
# -----

# %%
import numpy as np

np.mean(np.array(y_true) == np.array(y_pred))
# Out:
# np.float64(0.8751219512195122)

# %%
from sklearn.metrics import f1_score

# Should be 0.914 for straight classification
f1 = f1_score(y_true, y_pred, average='macro')
f1
# Out:
# 0.8796566600275575

# %%
f1 = f1_score(y_true, y_pred, average=None)

for idx, k in enumerate(event_types_mapping):
    print(k)
    print(f1[idx])
# Out:
# analyst rating
# 0.9082125603864735
# price targets
# 0.9924812030075187
# earnings
# 0.9166666666666666
# labour related
# 0.8862275449101796
# mergers and acquisitions
# 1.0
# dividends
# 0.8108108108108109
# regulatory
# 0.7375
# stock price movement
# 0.9482758620689655
# credit ratings
# 0.7962962962962963
# products-services
# 0.9007633587786259
# product approval
# 0.9440993788819876
# guidance
# 0.6666666666666666
# other
# 0.927536231884058

# %%
import pandas as pd

total_df = pd.read_csv("news_headlines_single_prediction_and_cot_legal_approved.csv")

total_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                             headline  \
# 0        Avago Technologies Announces $0.11 Dividend
# 1    Humana and Allscripts Form Alliance to Advan...
# 2   2011 Investor Day: UBS Updates its Strategy a...
# 3   24/7 Wall St. CEOs Who Need to be Fired: Nine...
# 4   3 ETFs Being Driven By Russia, Time Warner An...
#
#                                                  cot  cot_label  \
# 0  The headline mentions a specific dividend amou...  dividends
# 1  This headline mentions a partnership between t...      other
# 2  The headline mentions UBS updating its strateg...   guidance
# 3  The headline mentions CEOs who need to be fire...      other
# 4  The headline mentions specific entities (Russi...      other
#
#      direct_label
# 0       dividends
# 1           other
# 2        guidance
# 3  labour related
# 4           other

# %%
texts = total_df['headline'].to_list()
predictions = {}

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import threading


completed_tasks = 0  # Variable to track completed tasks
sub_texts = [text for text in texts if text not in predictions]
total_tasks = len(sub_texts)
lock = asyncio.Lock()  # To protect shared variables during concurrent access
predictions_accumulator = []
print(f'Total tasks: {total_tasks}')

def run(text):
    return llm.invoke(prompt.format(headline=text)).content


def save_item(item_to_save, file_name):
    with open(file_name, 'wb') as f:
        pickle.dump(item_to_save, f)
        

async def run_with_timeout(text, semaphore):
    global completed_tasks
    attempts = 0
    while True:
        attempts += 1
        try:
            async with semaphore:
                # Run the synchronous `run` function in a thread with a timeout
                result = await asyncio.wait_for(asyncio.to_thread(run, text), timeout=20)
            predictions[text] = result
            async with lock:
                completed_tasks += 1
                if completed_tasks % 500 == 0:
                    print(f"Completed {completed_tasks}/{total_tasks} tasks.")
                    save_item(predictions, "nemotron_super_49b_predictions.pkl")
            break  # Exit loop on success
        except asyncio.TimeoutError:
            # Retry if the request times out
            print(f"Task for '{text}' timed out. Retrying (attempt {attempts})...")
            continue
        except Exception as e:
            # Handle other exceptions if necessary
            print(f"Task for '{text}' failed with exception {e}. Retrying (attempt {attempts})...")
            continue

async def main():
    semaphore = asyncio.Semaphore(10)  # Limit to 10 concurrent tasks
    # tasks = [asyncio.create_task(run_with_timeout(text, semaphore)) for text in texts]
    tasks = [asyncio.create_task(run_with_timeout(text, semaphore)) for text in sub_texts]
    await asyncio.gather(*tasks)

asyncio.run(main())
# Out:
# Total tasks: 153511
# Completed 500/153511 tasks.
# Completed 1000/153511 tasks.
# Completed 1500/153511 tasks.
# Completed 2000/153511 tasks.
# Completed 2500/153511 tasks.
# Completed 3000/153511 tasks.
# Completed 3500/153511 tasks.
# Completed 4000/153511 tasks.
# Completed 4500/153511 tasks.
# Completed 5000/153511 tasks.
# Completed 5500/153511 tasks.
# Completed 6000/153511 tasks.
# Completed 6500/153511 tasks.
# Completed 7000/153511 tasks.
# Completed 7500/153511 tasks.
# Completed 8000/153511 tasks.
# Completed 8500/153511 tasks.
# Completed 9000/153511 tasks.
# Completed 9500/153511 tasks.
# Completed 10000/153511 tasks.
# Completed 10500/153511 tasks.
# Completed 11000/153511 tasks.
# Completed 11500/153511 tasks.
# Completed 12000/153511 tasks.

# %%
save_item(predictions, "nemotron_super_49b_predictions.pkl")

# %%
headlines = []
labels = []
cots = []


def clean_llm_prediction(pred):
    # try:
    pattern = r"\[\[(.*?)\]\]"
    # Find matches
    matches = re.findall(pattern, pred)
    try:
        pred = matches[0]
        pred = pred.replace(']]', '')
    except:
        pred = "other"
    pred = pred.lower() 
    for k in event_types_mapping:
        if k.lower() in pred:
            pred = k.lower()
            return pred
    return pred


for idx, t in enumerate(predictions):
    if t in dedup_headlines:
        headlines.append(t)
        labels.append(clean_llm_prediction(predictions[t], idx, t))
        cots.append(predictions[t])

# Check all the labels available for sanity check
set(labels)

# %%
final_df = pd.DataFrame({'headline': headlines, 'label': labels, 'cot': cots})

# %%
final_df.head()

# %%
final_df.to_csv("nemotron_event_type_fuzzy_deduplicated_cot.csv")

# %%
# Merge two dataframes -> single_label, cot_label, cot, headline
